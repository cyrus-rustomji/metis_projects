# %%
# For compatibility between Python 2 and Python 3
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

# To Plot matplotlib figures inline on the notebook
# %matplotlib inline
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
data = pd.read_csv('turnstile_180407.txt')
data.size
# Out:
# 2166868

# %% [markdown]
# # Field Description
# http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt
# C/A,UNIT,SCP,STATION,LINENAME,DIVISION,DATE,TIME,DESC,ENTRIES,EXITS
#
# ```
# C/A      = Control Area (A002)
# UNIT     = Remote Unit for a station (R051)
# SCP      = Subunit Channel Position represents an specific address for a device (02-00-00)
# STATION  = Represents the station name the device is located at
# LINENAME = Represents all train lines that can be boarded at this station
#            Normally lines are represented by one character.  LINENAME 456NQR repersents train server for 4, 5, 6, N, Q, and R trains.
# DIVISION = Represents the Line originally the station belonged to BMT, IRT, or IND
# DATE     = Represents the date (MM-DD-YY)
# TIME     = Represents the time (hh:mm:ss) for a scheduled audit event
# DESc     = Represent the "REGULAR" scheduled audit event (Normally occurs every 4 hours)
#            1. Audits may occur more that 4 hours due to planning, or troubleshooting activities.
#            2. Additionally, there may be a "RECOVR AUD" entry: This refers to a missed audit that was recovered.
# ENTRIES  = The comulative entry register value for a device
# EXIST    = The cumulative exit register value for a device
# ```

# %%
data=data.head(5000)
data
# Out:
#        C/A  UNIT       SCP         STATION  LINENAME DIVISION        DATE  \
# 0     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 1     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 2     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 3     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 4     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 5     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 6     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 7     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 8     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 9     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 10    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 11    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 12    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 13    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 14    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 15    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 16    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 17    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 18    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 19    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 20    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 21    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 22    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 23    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 24    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 25    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 26    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 27    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 28    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 29    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# ...    ...   ...       ...             ...       ...      ...         ...
# 4970  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/01/2018
# 4971  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/01/2018
# 4972  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/01/2018
# 4973  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4974  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4975  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4976  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4977  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4978  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4979  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4980  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4981  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4982  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4983  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4984  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4985  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4986  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4987  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4988  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4989  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4990  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4991  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4992  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4993  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4994  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4995  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4996  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4997  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/06/2018
# 4998  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/06/2018
# 4999  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/06/2018
#
#           TIME     DESC  ENTRIES  \
# 0     00:00:00  REGULAR  6566463
# 1     04:00:00  REGULAR  6566470
# 2     08:00:00  REGULAR  6566470
# 3     12:00:00  REGULAR  6566470
# 4     16:00:00  REGULAR  6566470
# 5     20:00:00  REGULAR  6566470
# 6     00:00:00  REGULAR  6566470
# 7     04:00:00  REGULAR  6566470
# 8     08:00:00  REGULAR  6566470
# 9     12:00:00  REGULAR  6566470
# 10    16:00:00  REGULAR  6566470
# 11    20:00:00  REGULAR  6566470
# 12    00:00:00  REGULAR  6566470
# 13    04:00:00  REGULAR  6566470
# 14    08:00:00  REGULAR  6566495
# 15    12:00:00  REGULAR  6566629
# 16    16:00:00  REGULAR  6566839
# 17    20:00:00  REGULAR  6567469
# 18    00:00:00  REGULAR  6567630
# 19    04:00:00  REGULAR  6567630
# 20    08:00:00  REGULAR  6567660
# 21    12:00:00  REGULAR  6567822
# 22    16:00:00  REGULAR  6568094
# 23    20:00:00  REGULAR  6568775
# 24    00:00:00  REGULAR  6568921
# 25    04:00:00  REGULAR  6568924
# 26    08:00:00  REGULAR  6568955
# 27    12:00:00  REGULAR  6569103
# 28    16:00:00  REGULAR  6569377
# 29    20:00:00  REGULAR  6570115
# ...        ...      ...      ...
# 4970  13:00:00  REGULAR  2983155
# 4971  17:00:00  REGULAR  2983618
# 4972  21:00:00  REGULAR  2984104
# 4973  01:00:00  REGULAR  2984254
# 4974  05:00:00  REGULAR  2984270
# 4975  09:00:00  REGULAR  2984405
# 4976  13:00:00  REGULAR  2984734
# 4977  17:00:00  REGULAR  2985362
# 4978  21:00:00  REGULAR  2986360
# 4979  01:00:00  REGULAR  2986645
# 4980  05:00:00  REGULAR  2986674
# 4981  09:00:00  REGULAR  2986827
# 4982  13:00:00  REGULAR  2987186
# 4983  17:00:00  REGULAR  2987763
# 4984  21:00:00  REGULAR  2988726
# 4985  01:00:00  REGULAR  2989034
# 4986  05:00:00  REGULAR  2989054
# 4987  09:00:00  REGULAR  2989208
# 4988  13:00:00  REGULAR  2989617
# 4989  17:00:00  REGULAR  2990373
# 4990  21:00:00  REGULAR  2991509
# 4991  01:00:00  REGULAR  2991823
# 4992  05:00:00  REGULAR  2991844
# 4993  09:00:00  REGULAR  2991980
# 4994  13:00:00  REGULAR  2992367
# 4995  17:00:00  REGULAR  2993207
# 4996  21:00:00  REGULAR  2994293
# 4997  01:00:00  REGULAR  2994644
# 4998  05:00:00  REGULAR  2994671
# 4999  09:00:00  REGULAR  2994803
#
#       EXITS
# 0                                               2224050
# 1                                               2224053
# 2                                               2224053
# 3                                               2224055
# 4                                               2224055
# 5                                               2224055
# 6                                               2224055
# 7                                               2224055
# 8                                               2224055
# 9                                               2224055
# 10                                              2224055
# 11                                              2224055
# 12                                              2224055
# 13                                              2224055
# 14                                              2224142
# 15                                              2224350
# 16                                              2224406
# 17                                              2224472
# 18                                              2224496
# 19                                              2224496
# 20                                              2224606
# 21                                              2224834
# 22                                              2224909
# 23                                              2225000
# 24                                              2225039
# 25                                              2225039
# 26                                              2225144
# 27                                              2225359
# 28                                              2225415
# 29                                              2225480
# ...                                                 ...
# 4970                                            2157578
# 4971                                            2157953
# 4972                                            2158165
# 4973                                            2158254
# 4974                                            2158271
# 4975                                            2158538
# 4976                                            2159027
# 4977                                            2159472
# 4978                                            2159846
# 4979                                            2159926
# 4980                                            2159937
# 4981                                            2160244
# 4982                                            2160855
# 4983                                            2161324
# 4984                                            2161709
# 4985                                            2161818
# 4986                                            2161835
# 4987                                            2162163
# 4988                                            2162785
# 4989                                            2163260
# 4990                                            2163716
# 4991                                            2163802
# 4992                                            2163814
# 4993                                            2164118
# 4994                                            2164693
# 4995                                            2165214
# 4996                                            2165696
# 4997                                            2165822
# 4998                                            2165842
# 4999                                            2166168
#
# [5000 rows x 11 columns]

# %% [markdown]
# # Challenge 1
# 1. Open up a new IPython notebook
# 2. Download a few MTA turnstile data files
# 3. Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
# ```
# { ('A002','R051','02-00-00','LEXINGTON AVE'): [ ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'], ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'], ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'], ... ] }
# ```

# %%
def create_dict(mtaData):
    result = {}
    for index, d in mtaData.iterrows():
        key = (d['C/A'], d['UNIT'], d['SCP'], d['STATION'])
        if key in result:
            result[key].append(list(d[4:]))
        else:
            result[key]=[list(d[4:])]
        return result;
result = create_dict(data)
print(result.keys())
# Out:
# dict_keys([('A002', 'R051', '02-00-00', '59 ST')])

# %%
print(result)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [['NQR456W', 'BMT', '03/31/2018', '00:00:00', 'REGULAR', 6566463, 2224050], ['NQR456W', 'BMT', '03/31/2018', '04:00:00', 'REGULAR', 6566470, 2224053], ['NQR456W', 'BMT', '03/31/2018', '08:00:00', 'REGULAR', 6566470, 2224053], ['NQR456W', 'BMT', '03/31/2018', '12:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '03/31/2018', '16:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '03/31/2018', '20:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/01/2018', '00:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/01/2018', '04:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/01/2018', '08:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/01/2018', '12:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/01/2018', '16:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/01/2018', '20:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/02/2018', '00:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/02/2018', '04:00:00', 'REGULAR', 6566470, 2224055], ['NQR456W', 'BMT', '04/02/2018', '08:00:00', 'REGULAR', 6566495, 2224142], ['NQR456W', 'BMT', '04/02/2018', '12:00:00', 'REGULAR', 6566629, 2224350], ['NQR456W', 'BMT', '04/02/2018', '16:00:00', 'REGULAR', 6566839, 2224406], ['NQR456W', 'BMT', '04/02/2018', '20:00:00', 'REGULAR', 6567469, 2224472], ['NQR456W', 'BMT', '04/03/2018', '00:00:00', 'REGULAR', 6567630, 2224496], ['NQR456W', 'BMT', '04/03/2018', '04:00:00', 'REGULAR', 6567630, 2224496], ['NQR456W', 'BMT', '04/03/2018', '08:00:00', 'REGULAR', 6567660, 2224606], ['NQR456W', 'BMT', '04/03/2018', '12:00:00', 'REGULAR', 6567822, 2224834], ['NQR456W', 'BMT', '04/03/2018', '16:00:00', 'REGULAR', 6568094, 2224909], ['NQR456W', 'BMT', '04/03/2018', '20:00:00', 'REGULAR', 6568775, 2225000], ['NQR456W', 'BMT', '04/04/2018', '00:00:00', 'REGULAR', 6568921, 2225039], ['NQR456W', 'BMT', '04/04/2018', '04:00:00', 'REGULAR', 6568924, 2225039], ['NQR456W', 'BMT', '04/04/2018', '08:00:00', 'REGULAR', 6568955, 2225144], ['NQR456W', 'BMT', '04/04/2018', '12:00:00', 'REGULAR', 6569103, 2225359], ['NQR456W', 'BMT', '04/04/2018', '16:00:00', 'REGULAR', 6569377, 2225415], ['NQR456W', 'BMT', '04/04/2018', '20:00:00', 'REGULAR', 6570115, 2225480], ['NQR456W', 'BMT', '04/05/2018', '00:00:00', 'REGULAR', 6570307, 2225512], ['NQR456W', 'BMT', '04/05/2018', '04:00:00', 'REGULAR', 6570307, 2225513], ['NQR456W', 'BMT', '04/05/2018', '08:00:00', 'REGULAR', 6570338, 2225613], ['NQR456W', 'BMT', '04/05/2018', '12:00:00', 'REGULAR', 6570480, 2225858], ['NQR456W', 'BMT', '04/05/2018', '16:00:00', 'REGULAR', 6570768, 2225920], ['NQR456W', 'BMT', '04/05/2018', '20:00:00', 'REGULAR', 6571500, 2225973], ['NQR456W', 'BMT', '04/06/2018', '00:00:00', 'REGULAR', 6571707, 2226010], ['NQR456W', 'BMT', '04/06/2018', '04:00:00', 'REGULAR', 6571711, 2226012], ['NQR456W', 'BMT', '04/06/2018', '08:00:00', 'REGULAR', 6571742, 2226097], ['NQR456W', 'BMT', '04/06/2018', '12:00:00', 'REGULAR', 6571888, 2226292], ['NQR456W', 'BMT', '04/06/2018', '16:00:00', 'REGULAR', 6572205, 2226369], ['NQR456W', 'BMT', '04/06/2018', '20:00:00', 'REGULAR', 6572929, 2226435]], ('A002', 'R051', '02-00-01', '59 ST'): [['NQR456W', 'BMT', '03/31/2018', '00:00:00', 'REGULAR', 5889283, 1316497], ['NQR456W', 'BMT', '03/31/2018', '04:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '03/31/2018', '08:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '03/31/2018', '12:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '03/31/2018', '16:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '03/31/2018', '20:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '04/01/2018', '00:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '04/01/2018', '04:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '04/01/2018', '08:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', '04/01/2018', '12:00:00', 'REGULAR', 5889285, 1316499], ['NQR456W', 'BMT', ...

# %% [markdown]
# # Challenge 2
# Let's turn this into a time series.
# For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the dateutil module to convert it into a datetime object. For an example check this StackOverflow question.
#
# Your new dict should look something like
#
# { ('A002','R051','02-00-00','LEXINGTON AVE'): [ [datetime.datetime(2013, 3, 2, 3, 0), 3788], [datetime.datetime(2013, 3, 2, 7, 0), 2585], [datetime.datetime(2013, 3, 2, 12, 0), 10653], [datetime.datetime(2013, 3, 2, 17, 0), 11016], [datetime.datetime(2013, 3, 2, 23, 0), 10666], [datetime.datetime(2013, 3, 3, 3, 0), 10814], [datetime.datetime(2013, 3, 3, 7, 0), 10229], ... ], .... }

# %%
import dateutil.parser

# %%
def to_time_series(mtaData):
    result2 = {}
    for index, d in mtaData.iterrows():
        key = (d['C/A'], d['UNIT'], d['SCP'], d['STATION'])
        dateCurrent = dateutil.parser.parse(d.DATE +' '+d.TIME)
        currRow=[dateCurrent, d.ENTRIES]
        if key in result2:
            result2[key].append(list(currRow))
        else:
            result2[key]=[list(currRow)]
    return result2;
result2 = to_time_series(data)
print(result2)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [[datetime.datetime(2018, 3, 31, 0, 0), 6566463], [datetime.datetime(2018, 3, 31, 4, 0), 6566470], [datetime.datetime(2018, 3, 31, 8, 0), 6566470], [datetime.datetime(2018, 3, 31, 12, 0), 6566470], [datetime.datetime(2018, 3, 31, 16, 0), 6566470], [datetime.datetime(2018, 3, 31, 20, 0), 6566470], [datetime.datetime(2018, 4, 1, 0, 0), 6566470], [datetime.datetime(2018, 4, 1, 4, 0), 6566470], [datetime.datetime(2018, 4, 1, 8, 0), 6566470], [datetime.datetime(2018, 4, 1, 12, 0), 6566470], [datetime.datetime(2018, 4, 1, 16, 0), 6566470], [datetime.datetime(2018, 4, 1, 20, 0), 6566470], [datetime.datetime(2018, 4, 2, 0, 0), 6566470], [datetime.datetime(2018, 4, 2, 4, 0), 6566470], [datetime.datetime(2018, 4, 2, 8, 0), 6566495], [datetime.datetime(2018, 4, 2, 12, 0), 6566629], [datetime.datetime(2018, 4, 2, 16, 0), 6566839], [datetime.datetime(2018, 4, 2, 20, 0), 6567469], [datetime.datetime(2018, 4, 3, 0, 0), 6567630], [datetime.datetime(2018, 4, 3, 4, 0), 6567630], [datetime.datetime(2018, 4, 3, 8, 0), 6567660], [datetime.datetime(2018, 4, 3, 12, 0), 6567822], [datetime.datetime(2018, 4, 3, 16, 0), 6568094], [datetime.datetime(2018, 4, 3, 20, 0), 6568775], [datetime.datetime(2018, 4, 4, 0, 0), 6568921], [datetime.datetime(2018, 4, 4, 4, 0), 6568924], [datetime.datetime(2018, 4, 4, 8, 0), 6568955], [datetime.datetime(2018, 4, 4, 12, 0), 6569103], [datetime.datetime(2018, 4, 4, 16, 0), 6569377], [datetime.datetime(2018, 4, 4, 20, 0), 6570115], [datetime.datetime(2018, 4, 5, 0, 0), 6570307], [datetime.datetime(2018, 4, 5, 4, 0), 6570307], [datetime.datetime(2018, 4, 5, 8, 0), 6570338], [datetime.datetime(2018, 4, 5, 12, 0), 6570480], [datetime.datetime(2018, 4, 5, 16, 0), 6570768], [datetime.datetime(2018, 4, 5, 20, 0), 6571500], [datetime.datetime(2018, 4, 6, 0, 0), 6571707], [datetime.datetime(2018, 4, 6, 4, 0), 6571711], [datetime.datetime(2018, 4, 6, 8, 0), 6571742], [datetime.datetime(2018, 4, 6, 12, 0), 6571888], [datetime.datetime(2018, 4, 6, 16, 0), 6572205], [datetime.datetime(2018, 4, 6, 20, 0), 6572929]], ('A002', 'R051', '02-00-01', '59 ST'): [[datetime.datetime(2018, 3, 31, 0, 0), 5889283], [datetime.datetime(2018, 3, 31, 4, 0), 5889285], [datetime.datetime(2018, 3, 31, 8, 0), 5889285], [datetime.datetime(2018, 3, 31, 12, 0), 5889285], [datetime.datetime(2018, 3, 31, 16, 0), 5889285], [datetime.datetime(2018, 3, 31, 20, 0), 5889285], [datetime.datetime(2018, 4, 1, 0, 0), 5889285], [datetime.datetime(2018, 4, 1, 4, 0), 5889285], [datetime.datetime(2018, 4, 1, 8, 0), 5889285], [datetime.datetime(2018, 4, 1, 12, 0), 5889285], [datetime.datetime(2018, 4, 1, 16, 0), 5889285], [datetime.datetime(2018, 4, 1, 20, 0), 5889285], [datetime.datetime(2018, 4, 2, 0, 0), 5889285], [datetime.datetime(2018, 4, 2, 4, 0), 5889285], [datetime.datetime(2018, 4, 2, 8, 0), 5889304], [datetime.datetime(2018, 4, 2, 12, 0), 5889414], [datetime.datetime(2018, 4, 2, 16, 0), 5889602], [datetime.datetime(2018, 4, 2, 20, 0), 5890117], [datetime.datetime(2018, 4, 3, 0, 0), 5890241], [datetime.datetime(2018, 4, 3, 4, 0), 5890244], [datetime.datetime(2018, 4, 3, 8, 0), 5890269], [datetime.datetime(2018, 4, 3, 12, 0), 5890396], [datetime.datetime(2018, 4, 3, 16, 0), 5890623], [datetime.datetime(2018, 4, 3, 20, 0), 5891152], [datetime.datetime(2018, 4, 4, 0, 0), 5891274], [datetime.datetime(2018, 4, 4, 4, 0), 5891275], [datetime.datetime(2018, 4, 4, 8, 0), 5891294], [datetime.datetime(2018, 4, 4, 12, 0), 5891411], [datetime.datetime(2018, 4, 4, 16, 0), 5891654], [datetime.datetime(2018, 4, 4, 20, 0), 5892222], [datetime.datetime(2018, 4, 5, 0, 0), 5892368], [datetime.datetime(2018, 4, 5, 4, 0), 5892371], [datetime.datetime(2018, 4, 5, 8, 0), 5892396], [datetime.datetime(2018, 4, 5, 12, 0), 5892522], [datetime.datetime(2018, 4, 5, 16, 0), 5892760], [datetime.datetime(2018, 4, 5, 20, 0), 5893342], [datetime.datetime(2018, 4, 6, 0, 0), 5893483], [datetime.datetime(2018, 4, 6, 4, 0), 5893484], [datetime.datetime(2018, 4, ...

# %% [markdown]
# # Challenge 3
# These counts are for every n hours. (What is n?) We want total daily entries.
# Now make it that we again have the same keys, but now we have a single value for a single day, which is the total number of passengers that entered through this turnstile on this day.

# %%
import sys

result3 = {}
for key, value in result2.items():
    date = '';
    min = sys.maxsize;
    max = -sys.maxsize -1
    result3[key] = {}    
    for v in value:
        trackingDate = v[0].date()
        date = v[0].date()
        if date==trackingDate:
            if min>v[-1]:
                min = v[-1]
            elif max<v[-1]:
                max = v[-1]
        else:
            min = v[-1]
        result3[key][trackingDate]=max-min                
print(result3)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): {datetime.date(2018, 3, 31): 7, datetime.date(2018, 4, 1): 7, datetime.date(2018, 4, 2): 1006, datetime.date(2018, 4, 3): 2312, datetime.date(2018, 4, 4): 3652, datetime.date(2018, 4, 5): 5037, datetime.date(2018, 4, 6): 6466}, ('A002', 'R051', '02-00-01', '59 ST'): {datetime.date(2018, 3, 31): 2, datetime.date(2018, 4, 1): 2, datetime.date(2018, 4, 2): 834, datetime.date(2018, 4, 3): 1869, datetime.date(2018, 4, 4): 2939, datetime.date(2018, 4, 5): 4059, datetime.date(2018, 4, 6): 5162}, ('A002', 'R051', '02-03-00', '59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 352, datetime.date(2018, 4, 3): 785, datetime.date(2018, 4, 4): 1256, datetime.date(2018, 4, 5): 1767, datetime.date(2018, 4, 6): 2276}, ('A002', 'R051', '02-03-01', '59 ST'): {datetime.date(2018, 3, 31): 3, datetime.date(2018, 4, 1): 3, datetime.date(2018, 4, 2): 903, datetime.date(2018, 4, 3): 2104, datetime.date(2018, 4, 4): 3317, datetime.date(2018, 4, 5): 4575, datetime.date(2018, 4, 6): 5809}, ('A002', 'R051', '02-03-02', '59 ST'): {datetime.date(2018, 3, 31): 5, datetime.date(2018, 4, 1): 5, datetime.date(2018, 4, 2): 985, datetime.date(2018, 4, 3): 2316, datetime.date(2018, 4, 4): 3627, datetime.date(2018, 4, 5): 4961, datetime.date(2018, 4, 6): 6255}, ('A002', 'R051', '02-03-03', '59 ST'): {datetime.date(2018, 3, 31): 9, datetime.date(2018, 4, 1): 9, datetime.date(2018, 4, 2): 982, datetime.date(2018, 4, 3): 2225, datetime.date(2018, 4, 4): 3421, datetime.date(2018, 4, 5): 4667, datetime.date(2018, 4, 6): 5900}, ('A002', 'R051', '02-03-04', '59 ST'): {datetime.date(2018, 3, 31): 5, datetime.date(2018, 4, 1): 5, datetime.date(2018, 4, 2): 1072, datetime.date(2018, 4, 3): 2462, datetime.date(2018, 4, 4): 3756, datetime.date(2018, 4, 5): 5211, datetime.date(2018, 4, 6): 6549}, ('A002', 'R051', '02-03-05', '59 ST'): {datetime.date(2018, 3, 31): 18, datetime.date(2018, 4, 1): 18, datetime.date(2018, 4, 2): 1543, datetime.date(2018, 4, 3): 3549, datetime.date(2018, 4, 4): 5614, datetime.date(2018, 4, 5): 7691, datetime.date(2018, 4, 6): 9572}, ('A002', 'R051', '02-03-06', '59 ST'): {datetime.date(2018, 3, 31): 2, datetime.date(2018, 4, 1): 2, datetime.date(2018, 4, 2): 1290, datetime.date(2018, 4, 3): 2964, datetime.date(2018, 4, 4): 4704, datetime.date(2018, 4, 5): 6439, datetime.date(2018, 4, 6): 8108}, ('A002', 'R051', '02-05-00', '59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 0, datetime.date(2018, 4, 3): 2, datetime.date(2018, 4, 4): 2, datetime.date(2018, 4, 5): 4, datetime.date(2018, 4, 6): 5}, ('A002', 'R051', '02-05-01', '59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 0, datetime.date(2018, 4, 3): 0, datetime.date(2018, 4, 4): 0, datetime.date(2018, 4, 5): 0, datetime.date(2018, 4, 6): 0}, ('A002', 'R051', '02-06-00', '59 ST'): {datetime.date(2018, 3, 31): 7, datetime.date(2018, 4, 1): 7, datetime.date(2018, 4, 2): 874, datetime.date(2018, 4, 3): 2010, datetime.date(2018, 4, 4): 3172, datetime.date(2018, 4, 5): 4378, datetime.date(2018, 4, 6): 5440}, ('A006', 'R079', '00-00-00', '5 AV/59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 1354, datetime.date(2018, 4, 3): 2909, datetime.date(2018, 4, 4): 4432, datetime.date(2018, 4, 5): 6013, datetime.date(2018, 4, 6): 7477}, ('A006', 'R079', '00-00-01', '5 AV/59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 1198, datetime.date(2018, 4, 3): 2678, datetime.date(2018, 4, 4): 4188, datetime.date(2018, 4, 5): 5676, datetime.date(2018, 4, 6): 7088}, ('A006', 'R079', '00-00-02', '5 AV/59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 958, datetime.date(2018, 4, 3): 2173, datetime.date(2018, 4, 4): 3337, datetime.date(2018, 4, 5): 4581, datetime.date(2018, 4, 6): 5644}, ('A006', 'R079' ...

# %% [markdown]
# # Challenge 4
#
# We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
#     %matplotlib inline
#
# This will make your matplotlib graphs integrate nicely with the
# notebook. To plot the time series, import matplotlib with
#
#     import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the
# turnstile and turn it into two lists:
# dates and counts. This should plot it:
#
#     plt.figure(figsize=(10,3))
#     plt.plot(dates,counts)

# %%
turnstile = list(result2.keys())[0]
dates, counts = zip(*result2[turnstile])
plt.figure(figsize=(10,3))
plt.plot(dates, counts);

# %% [markdown]
# # Challenge 5
#
# - So far we've been operating on a single turnstile level, let's
#   combine turnstiles in the same ControlArea/Unit/Station combo. There
#   are some ControlArea/Unit/Station groups that have a single
#   turnstile, but most have multiple turnstilea-- same value for the
#   C/A, UNIT and STATION columns, different values for the SCP column.
#
# We want to combine the numbers together -- for each
# ControlArea/UNIT/STATION combo, for each day, add the counts from each
# turnstile belonging to that combo.

# %% [markdown]
# # Challenge 6
#
# Similarly, combine everything in each station, and come up with a time
# series of `[(date1, count1),(date2,count2),...]` type of time series
# for each STATION, by adding up all the turnstiles in a station.

# %% [markdown]
# # Challenge 7
#
# Plot the time series for a station.

# %% [markdown]
# # Challenge 8
#
# - Make one list of counts for **one** week for one station. Monday's
# count, Tuesday's count, etc. so it's a list of 7 counts.
# Make the same list for another week, and another week, and another
# week.
# `plt.plot(week_count_list)` for every `week_count_list` you created
# this way. You should get a rainbow plot of weekly commute numbers on
# top of each other.

# %% [markdown]
# # Challenge 9
#
# - Over multiple weeks, sum total ridership for each station and sort
#   them, so you can find out the stations with the highest traffic
#   during the time you investigate

# %% [markdown]
# # Challenge 10
#
# - Make a single list of these total ridership values and plot it with
#
#     plt.hist(total_ridership_counts)
#
# to get an idea about the distribution of total ridership among
# different stations.
#
# This should show you that most stations have a small traffic, and the
# histogram bins for large traffic volumes have small bars.
#
# *Additional Hint*:
#
# If you want to see which stations take the meat of the traffic, you
# can sort the total ridership counts and make a `plt.bar` graph. For
# this, you want to have two lists: the indices of each bar, and the
# values. The indices can just be `0,1,2,3,...`, so you can do
#
#     indices = range(len(total_ridership_values))
#     plt.bar(indices, total_ridership_values)

# %%
data.STATION.unique()
# Out:
# array(['59 ST', '5 AV/59 ST', '57 ST-7 AV', '49 ST', 'TIMES SQ-42 ST',
#        '34 ST-HERALD SQ', '28 ST', '23 ST', '14 ST-UNION SQ'],
#       dtype=object)

# %%
data.STATION.value_counts()
# Out:
# 49 ST              933
# 34 ST-HERALD SQ    630
# 57 ST-7 AV         588
# 5 AV/59 ST         588
# 23 ST              587
# 59 ST              504
# 14 ST-UNION SQ     456
# 28 ST              378
# TIMES SQ-42 ST     336
# Name: STATION, dtype: int64

# %%
data.STATION.value_counts().keys()
# Out:
# Index(['49 ST', '34 ST-HERALD SQ', '57 ST-7 AV', '5 AV/59 ST', '23 ST',
#        '59 ST', '14 ST-UNION SQ', '28 ST', 'TIMES SQ-42 ST'],
#       dtype='object')

# %%
data.STATION.value_counts().plot(kind='barh')

# %%
stops = pd.read_csv('data/stops.txt')
stops.head()
# Out:
#   stop_id  stop_code                    stop_name  stop_desc   stop_lat  \
# 0     101        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 1    101N        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 2    101S        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 3     103        NaN                       238 St        NaN  40.884667
# 4    103N        NaN                       238 St        NaN  40.884667
#
#     stop_lon  zone_id  stop_url  location_type parent_station
# 0 -73.898583      NaN       NaN              1            NaN
# 1 -73.898583      NaN       NaN              0            101
# 2 -73.898583      NaN       NaN              0            101
# 3 -73.900870      NaN       NaN              1            NaN
# 4 -73.900870      NaN       NaN              0            103

# %%
stops.stop_name.value_counts()
# Out:
# Canal St                                  18
# 86 St                                     18
# Fulton St                                 15
# 23 St                                     15
# 145 St                                    12
# 96 St                                     12
# Times Sq - 42 St                          12
# 125 St                                    12
# Franklin Av                                9
# 72 St                                      9
# 111 St                                     9
# Broadway Jct                               9
# Chambers St                                9
# Church Av                                  9
# 103 St                                     9
# 28 St                                      9
# Kings Hwy                                  9
# 14 St                                      9
# Court Sq                                   9
# Grand Central - 42 St                      9
# Bay Pkwy                                   9
# Atlantic Av - Barclays Ctr                 9
# 116 St                                     9
# 7 Av                                       9
# 18 Av                                      9
# Avenue U                                   9
# Van Siclen Av                              9
# Fort Hamilton Pkwy                         9
# 50 St                                      9
# Borough Hall                               6
#                                           ..
# Bay Terrace                                3
# 53 St                                      3
# Pleasant Plains                            3
# 191 St                                     3
# 55 St                                      3
# 5 Av/53 St                                 3
# 231 St                                     3
# High St                                    3
# Beach 98 St                                3
# Avenue X                                   3
# Christopher St - Sheridan Sq               3
# Sutphin Blvd - Archer Av - JFK Airport     3
# Neck Rd                                    3
# Brooklyn Bridge - City Hall                3
# Carroll St                                 3
# Mets - Willets Point                       3
# 3 Av - 149 St                              3
# St Lawrence Av                             3
# Avenue M                                   3
# 49 St                                      3
# Beach 44 St                                3
# Newkirk Av                                 3
# Kew Gardens - Union Tpke                   3
# Norwood - 205 St                           3
# Middletown Rd                              3
# Van Cortlandt Park - 242 St                3
# 190 St                                     3
# Chauncey St                                3
# Parsons Blvd                               3
# Roosevelt Island                           3
# Name: stop_name, Length: 380, dtype: int64

# %%
#dict(stops.groupby('stop_name')['stop_lat', 'stop_lon'].apply(dict))
#np.unique(stops[['stop_name', 'stop_lat', 'stop_lon']].values)
#pd.unique(stops[['stop_name', 'stop_lat', 'stop_lon']].values)
resultT = dict(stops.drop_duplicates('stop_name').groupby(['stop_name','stop_lat', 'stop_lon'])['stop_name'].apply(list))
stops_dict = resultT.keys()
# Out:
# dict_keys([('1 Av', 40.730953, -73.981628), ('103 St', 40.799446, -73.968379), ('103 St - Corona Plaza', 40.749865, -73.8627), ('104 St', 40.681711, -73.837683), ('110 St', 40.79502, -73.94425), ('111 St', 40.75173, -73.855334), ('116 St', 40.802098, -73.949625), ('116 St - Columbia University', 40.807722, -73.96410999999999), ('121 St', 40.700492, -73.828294), ('125 St', 40.815581, -73.958372), ('135 St', 40.814229, -73.94077), ('137 St - City College', 40.822008000000004, -73.953676), ('138 St - Grand Concourse', 40.813224, -73.929849), ('14 St', 40.737826, -74.000201), ('14 St - Union Sq', 40.734673, -73.989951), ('145 St', 40.826551, -73.95036), ('149 St - Grand Concourse', 40.81841, -73.92671800000001), ('15 St - Prospect Park', 40.660365000000006, -73.979493), ('155 St', 40.830518, -73.941514), ('157 St', 40.834041, -73.94489), ('161 St - Yankee Stadium', 40.827994, -73.925831), ('163 St - Amsterdam Av', 40.836013, -73.939892), ('167 St', 40.835537, -73.9214), ('168 St', 40.840719, -73.939561), ('168 St - Washington Hts', 40.840556, -73.94013299999999), ('169 St', 40.71047, -73.793604), ('170 St', 40.840075, -73.91779100000001), ('174 St', 40.837288, -73.887734), ('174-175 Sts', 40.8459, -73.910136), ('175 St', 40.847390999999995, -73.939704), ('176 St', 40.84848, -73.911794), ('18 Av', 40.607954, -74.001736), ('18 St', 40.741040000000005, -73.99787099999999), ('181 St', 40.849505, -73.933596), ('182-183 Sts', 40.856093, -73.900741), ('183 St', 40.858407, -73.903879), ('190 St', 40.859021999999996, -73.93418), ('191 St', 40.855225, -73.929412), ('2 Av', 40.723402, -73.989938), ('20 Av', 40.604556, -73.998168), ('207 St', 40.864621, -73.91882199999999), ('21 St', 40.744065, -73.949724), ('21 St - Queensbridge', 40.754203000000004, -73.942836), ('215 St', 40.869444, -73.915279), ('219 St', 40.883895, -73.862633), ('225 St', 40.888022, -73.860341), ('23 St', 40.744081, -73.995657), ('231 St', 40.878856, -73.904834), ('233 St', 40.893193, -73.857473), ('238 St', 40.884667, -73.90087), ('25 Av', 40.597704, -73.986829), ('25 St', 40.660396999999996, -73.998091), ('28 St', 40.747215000000004, -73.993365), ('3 Av', 40.732849, -73.986122), ('3 Av - 138 St', 40.810476, -73.926138), ('3 Av - 149 St', 40.816109000000004, -73.917757), ('30 Av', 40.766779, -73.921479), ('33 St', 40.746081, -73.982076), ('34 St - 11 Av', 40.755882, -74.00191), ('34 St - Herald Sq', 40.749719, -73.98782299999999), ('34 St - Penn Station', 40.750372999999996, -73.991057), ('36 Av', 40.756803999999995, -73.929575), ('36 St', 40.752039, -73.928781), ('39 Av', 40.752882, -73.932755), ('4 Av', 40.670272, -73.989779), ('40 St', 40.743781, -73.92401600000001), ('42 St - Bryant Pk', 40.754222, -73.984569), ('42 St - Port Authority Bus Terminal', 40.757308, -73.989735), ('45 St', 40.648939, -74.010006), ('46 St', 40.743132, -73.918435), ('47-50 Sts - Rockefeller Ctr', 40.758663, -73.981329), ('49 St', 40.759901, -73.984139), ('5 Av', 40.753821, -73.98196300000001), ('5 Av/53 St', 40.760166999999996, -73.975224), ('5 Av/59 St', 40.764811, -73.973347), ('50 St', 40.761728000000005, -73.98384899999999), ('51 St', 40.757107, -73.97192), ('52 St', 40.744149, -73.912549), ('53 St', 40.645069, -74.014034), ('55 St', 40.631434999999996, -73.995476), ('57 St', 40.763971999999995, -73.97745), ('57 St - 7 Av', 40.764664, -73.98065799999999), ('59 St', 40.762526, -73.967967), ('59 St - Columbus Circle', 40.768246999999995, -73.98192900000001), ('6 Av', 40.737334999999995, -73.996786), ('62 St', 40.626472, -73.996895), ('63 Dr - Rego Park', 40.729846, -73.861604), ('65 St', 40.749669, -73.898453), ('66 St - Lincoln Center', 40.77344, -73.982209), ('67 Av', 40.726523, -73.852719), ('68 St - Hunter College', 40.768141, -73.96387), ('69 St', 40.746325, -73.896403), ('7 Av', 40.762862, -73.981637), ('71 St', 40.619589000000005, -73.998864), ('72 St', 40.778453000000006, -73.98196999999999), ('74 St - Broadway', 40.746848, -73.89139399999999), ('75 Av', 40.718331, -73.837324), (' ...

# %%
#for key, value in result3.items():

# %%
#run pip3 install gmaps beforehand
# %matplotlib inline
import gmaps
import math
gmaps.configure(api_key="AIzaSyCM2FKc59VWg6jMI8nj9kN1Gii3DHsGNnE")
location_columns = stops[['stop_lat', 'stop_lon']]
location_tuples = [tuple(x) for x in location_columns.values]
fig = gmaps.figure(zoom_level=12, center=(40.7, -73.9))
fig.add_layer(gmaps.heatmap_layer(location_tuples))
#stops_layer = gmaps.symbol_layer(location_columns, fill_color="green", stroke_color="green", scale=2)
#fig.add_layer(stops_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
trips = pd.read_csv('data/trips.txt')
trips.head()
# Out:
#   route_id    service_id                      trip_id          trip_headsign  \
# 0       GS  A20171105SAT  A20171105SAT_036000_GS.N01R       TIMES SQ - 42 ST
# 1       GS  A20171105SAT  A20171105SAT_036400_GS.S01R  GRAND CENTRAL - 42 ST
# 2       GS  A20171105SAT  A20171105SAT_037000_GS.N01R       TIMES SQ - 42 ST
# 3       GS  A20171105SAT  A20171105SAT_037400_GS.S01R  GRAND CENTRAL - 42 ST
# 4       GS  A20171105SAT  A20171105SAT_038000_GS.N01R       TIMES SQ - 42 ST
#
#    direction_id  block_id shape_id
# 0             0       NaN  GS.N01R
# 1             1       NaN  GS.S01R
# 2             0       NaN  GS.N01R
# 3             1       NaN  GS.S01R
# 4             0       NaN  GS.N01R

# %%
routes = pd.read_csv('data/routes.txt')
routes.head()
# Out:
#   route_id agency_id route_short_name            route_long_name  \
# 0        1  MTA NYCT                1  Broadway - 7 Avenue Local
# 1        2  MTA NYCT                2           7 Avenue Express
# 2        3  MTA NYCT                3           7 Avenue Express
# 3        4  MTA NYCT                4   Lexington Avenue Express
# 4        5  MTA NYCT                5   Lexington Avenue Express
#
#                                           route_desc  route_type  \
# 0  Trains operate between 242 St in the Bronx and...           1
# 1  Trains operate between Wakefield-241 St, Bronx...           1
# 2  Trains operate between 148 St, 7 Av, Manhattan...           1
# 3  Trains operate daily between Woodlawn/Jerome A...           1
# 4  Weekdays daytime, most trains operate between ...           1
#
#                                         route_url route_color route_text_color
# 0  http://web.mta.info/nyct/service/pdf/t1cur.pdf      EE352E              NaN
# 1  http://web.mta.info/nyct/service/pdf/t2cur.pdf      EE352E
# 2  http://web.mta.info/nyct/service/pdf/t3cur.pdf      EE352E              NaN
# 3  http://web.mta.info/nyct/service/pdf/t4cur.pdf      00933C              NaN
# 4  http://web.mta.info/nyct/service/pdf/t5cur.pdf      00933C              NaN

# %% [markdown]
# # Other data set

# %%
import urllib.request
import requests
headers = {"Authorization":"Bearer 421BA_xYdh0Xq7dGFe1pkaI7WqWnJ5UcHZZgg8WwNQ34_7GlbvrRU4dnCGE9dmXOZrX5xVFquiL9X4B35qBuBcA4Jt1D9ys3h0z6pxnfFd8Frf9UYXQ9xKMDOnjNWnYx"}
endpoint = 'https://api.yelp.com/v3/businesses/search?location=new york&limit=50'

#yelpData = requests.get(endpoint,headers=headers).json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-da442cc573cd> in <module>()
#       4 endpoint = 'https://api.yelp.com/v3/businesses/search?location=new york'
#       5
# ----> 6 yelpData = requests.get(endpoint,headers=headers).json().businesses
#       7 for r in yelpdata:
#       8     pp.pprint(r)
#
# AttributeError: 'dict' object has no attribute 'businesses'

# %%
#print(yelpData)
yData= yelpData['businesses']
print(len(yData))
for r in yData:
    pp.pprint(r)
    #pp.pprint(r['coordinates'])
# Out:
# 20
# {   'alias': 'the-halal-guys-new-york-2',
#     'categories': [   {'alias': 'foodstands', 'title': 'Food Stands'},
#                       {'alias': 'mideastern', 'title': 'Middle Eastern'},
#                       {'alias': 'halal', 'title': 'Halal'}],
#     'coordinates': {   'latitude': 40.7617559582706,
#                        'longitude': -73.979229927063},
#     'display_phone': '',
#     'distance': 6377.393393302603,
#     'id': 'xEnNFXtMLDF5kZDxfaCJgA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i6QRVRliZ42stZUp7795jQ/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': 'W 53rd St 6th Ave',
#                     'address2': None,
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': [   'W 53rd St 6th Ave',
#                                            'New York, NY 10019'],
#                     'state': 'NY',
#                     'zip_code': '10019'},
#     'name': 'The Halal Guys',
#     'phone': '',
#     'price': '$',
#     'rating': 4.5,
#     'review_count': 8736,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/the-halal-guys-new-york-2?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'ippudo-east-village-new-york',
#     'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#     'coordinates': {'latitude': 40.730922, 'longitude': -73.990167},
#     'display_phone': '',
#     'distance': 2844.1654214921264,
#     'id': '44SY464xDHbvOcjDzRbKkQ',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vD-5ypZnkzaqiF3mlurg2Q/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '65 4th Ave',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['65 4th Ave', 'New York, NY 10003'],
#                     'state': 'NY',
#                     'zip_code': '10003'},
#     'name': 'Ippudo East Village',
#     'phone': '',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 9245,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/ippudo-east-village-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'katzs-delicatessen-new-york',
#     'categories': [   {'alias': 'delis', 'title': 'Delis'},
#                       {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'coordinates': {'latitude': 40.72222, 'longitude': -73.98751},
#     'display_phone': '(212) 254-2246',
#     'distance': 1939.3533072280202,
#     'id': 'V7lXZKBDzScDeGB8JmnzSA',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qr7eSU6CFwRGZ7Rc-QEoTQ/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '205 E Houston St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': [   '205 E Houston St',
#                                            'New York, NY 10002'],
#                     'state': 'NY',
#                     'zip_code': '10002'},
#     'name': "Katz's Delicatessen",
#     'phone': '+12122542246',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 8739,
#     'transactions': ['delivery', 'pickup'],
#     'url': 'https://www.yelp.com/biz/katzs-delicatessen-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'central-park-new-york',
#     'categories': [{'alias': 'parks', 'title': 'Parks'}],
#     'coordinates': {   'latitude': 40.782418740809,
#                        'longitude': -73.9656022837641},
#     'display_phone': '(212) 310-6600',
#     'distance': 8882.403095579268,
#     'id': 'xOw4aafJRji9XomGunlvcQ',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oQQIa-DExchCgEyOHsrHCw/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '14 E 60th St',
#                     'address2': '',
#                     'address3': 'Central Park Conservancy',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': [   '14 E 60th St',
#                                            'Central Park Conservancy',
#                                            'New York, NY 10022'],
#                     'state': 'NY',
#                     'zip_code': '10022'},
#     'name': 'Central Park',
#     'phone': '+12123106600',
#     'rating': 5.0,
#     'review_count': 2000,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/central-park-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'doughnut-plant-new-york-4',
#     'categories': [   {'alias': 'donuts', 'title': 'Donuts'},
#                       {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#     'coordinates': {   'latitude': 40.7163944930004,
#                        'longitude': -73.9886098620298},
#     'display_phone': '(212) 505-3700',
#     'distance': 1297.073762620505,
#     'id': 'lWOkeS-wV4no8qqA9OwwEg',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ByIdPZzld6KNutaZr2rlOg/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '379 Grand St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['379 Grand St', 'New York, NY 10002'],
#                     'state': 'NY',
#                     'zip_code': '10002'},
#     'name': 'Doughnut Plant',
#     'phone': '+12125053700',
#     'price': '$$',
#     'rating': 4.5,
#     'review_count': 2971,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/doughnut-plant-new-york-4?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'burger-and-lobster-new-york',
#     'categories': [   {'alias': 'seafood', 'title': 'Seafood'},
#                       {'alias': 'burgers', 'title': 'Burgers'}],
#     'coordinates': {'latitude': 40.74016, 'longitude': -73.993372},
#     'display_phone': '(646) 833-7532',
#     'distance': 3849.707237413338,
#     'id': 'UA2M9QFZghe-9th2KwLoWQ',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ysH4wU0R13y3N3jG7GYFrw/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '39 W 19th St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['39 W 19th St', 'New York, NY 10011'],
#                     'state': 'NY',
#                     'zip_code': '10011'},
#     'name': 'Burger & Lobster',
#     'phone': '+16468337532',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 4229,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'gramercy-tavern-new-york',
#     'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#     'coordinates': {'latitude': 40.738527, 'longitude': -73.988417},
#     'display_phone': '(212) 477-0777',
#     'distance': 3700.3394832964277,
#     'id': 'veq1Bl1DW3UWMekZJUsG1Q',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yr_BNXJ57Q66IgSppMy1Qw/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '42 E 20th St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['42 E 20th St', 'New York, NY 10003'],
#                     'state': 'NY',
#                     'zip_code': '10003'},
#     'name': 'Gramercy Tavern',
#     'phone': '+12124770777',
#     'price': '$$$$',
#     'rating': 4.5,
#     'review_count': 2449,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/gramercy-tavern-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'the-high-line-new-york',
#     'categories': [   {'alias': 'parks', 'title': 'Parks'},
#                       {'alias': 'localflavor', 'title': 'Local Flavor'}],
#     'coordinates': {   'latitude': 40.7479831752801,
#                        'longitude': -74.0048906107511},
#     'display_phone': '(212) 206-9922',
#     'distance': 4803.093773433433,
#     'id': 'JION8hhg7q6zyayHYwhxIw',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A-WMM_ocFEi2Su4_UaZIow/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '820 Washington St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': [   '820 Washington St',
#                                            'New York, NY 10014'],
#                     'state': 'NY',
#                     'zip_code': '10014'},
#     'name': 'The High Line',
#     'phone': '+12122069922',
#     'rating': 4.5,
#     'review_count': 2075,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/the-high-line-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'los-tacos-no-1-new-york',
#     'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#     'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#     'display_phone': '(212) 256-0343',
#     'distance': 4234.093260830913,
#     'id': 'jnEv25Y2DosTq2sNnvmC9g',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '75 9th Ave',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['75 9th Ave', 'New York, NY 10011'],
#                     'state': 'NY',
#                     'zip_code': '10011'},
#     'name': 'Los Tacos No.1',
#     'phone': '+12122560343',
#     'price': '$',
#     'rating': 4.5,
#     'review_count': 2117,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'shake-shack-new-york-2',
#     'categories': [   {'alias': 'burgers', 'title': 'Burgers'},
#                       {'alias': 'foodstands', 'title': 'Food Stands'},
#                       {   'alias': 'icecream',
#                           'title': 'Ice Cream & Frozen Yogurt'}],
#     'coordinates': {'latitude': 40.7414000197233, 'longitude': -73.98815019045},
#     'display_phone': '(212) 889-6600',
#     'distance': 4020.0033084180022,
#     'id': 'FEVQpbOPOwAPNIgO7D3xxw',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J0UoRJKdaMl0EPdgxYIlKw/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': 'Madison Square Park',
#                     'address2': '',
#                     'address3': 'E 23rd St & Madison Ave',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': [   'Madison Square Park',
#                                            'E 23rd St & Madison Ave',
#                                            'New York, NY 10010'],
#                     'state': 'NY',
#                     'zip_code': '10010'},
#     'name': 'Shake Shack',
#     'phone': '+12128896600',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 5344,
#     'transactions': ['restaurant_reservation', 'delivery'],
#     'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'peter-luger-brooklyn-2',
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#     'coordinates': {'latitude': 40.709945, 'longitude': -73.962478},
#     'display_phone': '(718) 387-7400',
#     'distance': 2723.5099306751026,
#     'id': '4yPqqJDJOQX69gC66YUDkA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DnReRUkXRtsmKycQEYl0pg/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '178 Broadway',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'Brooklyn',
#                     'country': 'US',
#                     'display_address': ['178 Broadway', 'Brooklyn, NY 11211'],
#                     'state': 'NY',
#                     'zip_code': '11211'},
#     'name': 'Peter Luger',
#     'phone': '+17183877400',
#     'price': '$$$$',
#     'rating': 4.0,
#     'review_count': 4560,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/peter-luger-brooklyn-2?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'bibble-and-sip-new-york-2',
#     'categories': [   {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                       {'alias': 'bakeries', 'title': 'Bakeries'}],
#     'coordinates': {'latitude': 40.76282, 'longitude': -73.98518},
#     'display_phone': '(646) 649-5116',
#     'distance': 6421.976948423399,
#     'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zCUvBD2KTMNEps7TAuuecQ/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '253 W 51st St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['253 W 51st St', 'New York, NY 10019'],
#                     'state': 'NY',
#                     'zip_code': '10019'},
#     'name': 'Bibble & Sip',
#     'phone': '+16466495116',
#     'price': '$',
#     'rating': 4.5,
#     'review_count': 3227,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'le-bernardin-new-york',
#     'categories': [   {'alias': 'french', 'title': 'French'},
#                       {'alias': 'lounges', 'title': 'Lounges'}],
#     'coordinates': {'latitude': 40.761557, 'longitude': -73.981763},
#     'display_phone': '(212) 554-1515',
#     'distance': 6316.639756903092,
#     'id': 'vRrVSB-LegwUwIxpkeRVtQ',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O2auTfVN7mp7qSMoKQ81hQ/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '155 W 51st St',
#                     'address2': '',
#                     'address3': 'The Equitable Bldg',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': [   '155 W 51st St',
#                                            'The Equitable Bldg',
#                                            'New York, NY 10019'],
#                     'state': 'NY',
#                     'zip_code': '10019'},
#     'name': 'Le Bernardin',
#     'phone': '+12125541515',
#     'price': '$$$$',
#     'rating': 4.5,
#     'review_count': 2096,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/le-bernardin-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'clinton-street-baking-company-new-york-5',
#     'categories': [   {'alias': 'bakeries', 'title': 'Bakeries'},
#                       {   'alias': 'breakfast_brunch',
#                           'title': 'Breakfast & Brunch'},
#                       {   'alias': 'tradamerican',
#                           'title': 'American (Traditional)'}],
#     'coordinates': {'latitude': 40.721128, 'longitude': -73.983933},
#     'display_phone': '(646) 602-6263',
#     'distance': 1939.170188721576,
#     'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1CTyUp3Fz_svoqmvi7hwAw/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '4 Clinton St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['4 Clinton St', 'New York, NY 10002'],
#                     'state': 'NY',
#                     'zip_code': '10002'},
#     'name': 'Clinton Street Baking Company',
#     'phone': '+16466026263',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 4042,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'two-little-red-hens-new-york-4',
#     'categories': [   {'alias': 'bakeries', 'title': 'Bakeries'},
#                       {'alias': 'desserts', 'title': 'Desserts'},
#                       {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#     'coordinates': {'latitude': 40.777528, 'longitude': -73.9517869},
#     'display_phone': '(212) 452-0476',
#     'distance': 8767.650145162921,
#     'id': 'UGECJrPSWy0n7PXykBBWAQ',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gF02Oh2PfE2OS7Nz3MqV4g/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '1652 2nd Ave',
#                     'address2': None,
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['1652 2nd Ave', 'New York, NY 10028'],
#                     'state': 'NY',
#                     'zip_code': '10028'},
#     'name': 'Two Little Red Hens',
#     'phone': '+12124520476',
#     'price': '$$',
#     'rating': 4.5,
#     'review_count': 2145,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/two-little-red-hens-new-york-4?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'brooklyn-bridge-brooklyn',
#     'categories': [   {   'alias': 'landmarks',
#                           'title': 'Landmarks & Historical Buildings'}],
#     'coordinates': {   'latitude': 40.7059677364821,
#                        'longitude': -73.9966657489186},
#     'display_phone': '(718) 724-6434',
#     'distance': 207.88480113464703,
#     'id': 'mvn2XFJfIPNAlvsy-arzkA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xMLer6u7sMowolpZevqPzA/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '334 Furman St',
#                     'address2': None,
#                     'address3': '',
#                     'city': 'Brooklyn',
#                     'country': 'US',
#                     'display_address': ['334 Furman St', 'Brooklyn, NY 11201'],
#                     'state': 'NY',
#                     'zip_code': '11201'},
#     'name': 'Brooklyn Bridge',
#     'phone': '+17187246434',
#     'rating': 4.5,
#     'review_count': 1169,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/brooklyn-bridge-brooklyn?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'buddakan-new-york',
#     'categories': [   {'alias': 'chinese', 'title': 'Chinese'},
#                       {'alias': 'bars', 'title': 'Bars'},
#                       {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#     'coordinates': {   'latitude': 40.7422762672197,
#                        'longitude': -74.0048000961542},
#     'display_phone': '(212) 989-6699',
#     'distance': 4179.698118919742,
#     'id': 'nI1UYDCYUTt23TpGxqnLKg',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Avw19VU35-FZLen3nl9gYw/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '75 9th Ave',
#                     'address2': None,
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['75 9th Ave', 'New York, NY 10011'],
#                     'state': 'NY',
#                     'zip_code': '10011'},
#     'name': 'Buddakan',
#     'phone': '+12129896699',
#     'price': '$$$',
#     'rating': 4.0,
#     'review_count': 3369,
#     'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#     'url': 'https://www.yelp.com/biz/buddakan-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'lombardis-pizza-new-york',
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'coordinates': {'latitude': 40.721515, 'longitude': -73.995735},
#     'display_phone': '(212) 941-7994',
#     'distance': 1781.5228678391722,
#     'id': 'WIhm0W9197f_rRtDziq5qQ',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XtCyVQ08bShUv8WdK5B-VA/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '32 Spring St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['32 Spring St', 'New York, NY 10012'],
#                     'state': 'NY',
#                     'zip_code': '10012'},
#     'name': "Lombardi's Pizza",
#     'phone': '+12129417994',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 5377,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'eataly-new-york',
#     'categories': [   {'alias': 'italian', 'title': 'Italian'},
#                       {'alias': 'grocery', 'title': 'Grocery'},
#                       {'alias': 'cafes', 'title': 'Cafes'}],
#     'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#     'display_phone': '(212) 229-2560',
#     'distance': 4067.077153708126,
#     'id': 'a0IET3_yCFcO36OqGSsisg',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4bpuD2hPIGdAGCp-gtrPtQ/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '200 5th Ave',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['200 5th Ave', 'New York, NY 10010'],
#                     'state': 'NY',
#                     'zip_code': '10010'},
#     'name': 'Eataly',
#     'phone': '+12122292560',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 4795,
#     'transactions': ['restaurant_reservation'],
#     'url': 'https://www.yelp.com/biz/eataly-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
# {   'alias': 'totto-ramen-new-york',
#     'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#     'coordinates': {   'latitude': 40.7643285462369,
#                        'longitude': -73.9876558773155},
#     'display_phone': '(212) 582-0052',
#     'distance': 6560.056808972491,
#     'id': '-134ZvJ4lgiqx-sjRBWQ9g',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tJh6-nAiwlPsRLNNnOYXGg/o.jpg',
#     'is_closed': False,
#     'location': {   'address1': '366 W 52nd St',
#                     'address2': '',
#                     'address3': '',
#                     'city': 'New York',
#                     'country': 'US',
#                     'display_address': ['366 W 52nd St', 'New York, NY 10019'],
#                     'state': 'NY',
#                     'zip_code': '10019'},
#     'name': 'Totto Ramen',
#     'phone': '+12125820052',
#     'price': '$$',
#     'rating': 4.0,
#     'review_count': 4757,
#     'transactions': [],
#     'url': 'https://www.yelp.com/biz/totto-ramen-new-york?adjust_creative=WRlSglHD_EXIqERZusddPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WRlSglHD_EXIqERZusddPQ'}
