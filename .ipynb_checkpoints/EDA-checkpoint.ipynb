# %%
# For compatibility between Python 2 and Python 3
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

# To Plot matplotlib figures inline on the notebook
# %matplotlib inline
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
data = pd.read_csv('turnstile_180407.txt')
data.size
# Out:
# 2166868

# %% [markdown]
# # Field Description
# http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt
# C/A,UNIT,SCP,STATION,LINENAME,DIVISION,DATE,TIME,DESC,ENTRIES,EXITS
#
# ```
# C/A      = Control Area (A002)
# UNIT     = Remote Unit for a station (R051)
# SCP      = Subunit Channel Position represents an specific address for a device (02-00-00)
# STATION  = Represents the station name the device is located at
# LINENAME = Represents all train lines that can be boarded at this station
#            Normally lines are represented by one character.  LINENAME 456NQR repersents train server for 4, 5, 6, N, Q, and R trains.
# DIVISION = Represents the Line originally the station belonged to BMT, IRT, or IND
# DATE     = Represents the date (MM-DD-YY)
# TIME     = Represents the time (hh:mm:ss) for a scheduled audit event
# DESc     = Represent the "REGULAR" scheduled audit event (Normally occurs every 4 hours)
#            1. Audits may occur more that 4 hours due to planning, or troubleshooting activities.
#            2. Additionally, there may be a "RECOVR AUD" entry: This refers to a missed audit that was recovered.
# ENTRIES  = The comulative entry register value for a device
# EXIST    = The cumulative exit register value for a device
# ```

# %%
data=data.head(5000)
data
# Out:
#        C/A  UNIT       SCP         STATION  LINENAME DIVISION        DATE  \
# 0     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 1     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 2     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 3     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 4     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 5     A002  R051  02-00-00           59 ST   NQR456W      BMT  03/31/2018
# 6     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 7     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 8     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 9     A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 10    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 11    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/01/2018
# 12    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 13    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 14    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 15    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 16    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 17    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/02/2018
# 18    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 19    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 20    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 21    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 22    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 23    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/03/2018
# 24    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 25    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 26    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 27    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 28    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# 29    A002  R051  02-00-00           59 ST   NQR456W      BMT  04/04/2018
# ...    ...   ...       ...             ...       ...      ...         ...
# 4970  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/01/2018
# 4971  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/01/2018
# 4972  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/01/2018
# 4973  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4974  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4975  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4976  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4977  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4978  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/02/2018
# 4979  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4980  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4981  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4982  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4983  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4984  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/03/2018
# 4985  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4986  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4987  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4988  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4989  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4990  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/04/2018
# 4991  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4992  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4993  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4994  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4995  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4996  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/05/2018
# 4997  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/06/2018
# 4998  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/06/2018
# 4999  A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  04/06/2018
#
#           TIME     DESC  ENTRIES  \
# 0     00:00:00  REGULAR  6566463
# 1     04:00:00  REGULAR  6566470
# 2     08:00:00  REGULAR  6566470
# 3     12:00:00  REGULAR  6566470
# 4     16:00:00  REGULAR  6566470
# 5     20:00:00  REGULAR  6566470
# 6     00:00:00  REGULAR  6566470
# 7     04:00:00  REGULAR  6566470
# 8     08:00:00  REGULAR  6566470
# 9     12:00:00  REGULAR  6566470
# 10    16:00:00  REGULAR  6566470
# 11    20:00:00  REGULAR  6566470
# 12    00:00:00  REGULAR  6566470
# 13    04:00:00  REGULAR  6566470
# 14    08:00:00  REGULAR  6566495
# 15    12:00:00  REGULAR  6566629
# 16    16:00:00  REGULAR  6566839
# 17    20:00:00  REGULAR  6567469
# 18    00:00:00  REGULAR  6567630
# 19    04:00:00  REGULAR  6567630
# 20    08:00:00  REGULAR  6567660
# 21    12:00:00  REGULAR  6567822
# 22    16:00:00  REGULAR  6568094
# 23    20:00:00  REGULAR  6568775
# 24    00:00:00  REGULAR  6568921
# 25    04:00:00  REGULAR  6568924
# 26    08:00:00  REGULAR  6568955
# 27    12:00:00  REGULAR  6569103
# 28    16:00:00  REGULAR  6569377
# 29    20:00:00  REGULAR  6570115
# ...        ...      ...      ...
# 4970  13:00:00  REGULAR  2983155
# 4971  17:00:00  REGULAR  2983618
# 4972  21:00:00  REGULAR  2984104
# 4973  01:00:00  REGULAR  2984254
# 4974  05:00:00  REGULAR  2984270
# 4975  09:00:00  REGULAR  2984405
# 4976  13:00:00  REGULAR  2984734
# 4977  17:00:00  REGULAR  2985362
# 4978  21:00:00  REGULAR  2986360
# 4979  01:00:00  REGULAR  2986645
# 4980  05:00:00  REGULAR  2986674
# 4981  09:00:00  REGULAR  2986827
# 4982  13:00:00  REGULAR  2987186
# 4983  17:00:00  REGULAR  2987763
# 4984  21:00:00  REGULAR  2988726
# 4985  01:00:00  REGULAR  2989034
# 4986  05:00:00  REGULAR  2989054
# 4987  09:00:00  REGULAR  2989208
# 4988  13:00:00  REGULAR  2989617
# 4989  17:00:00  REGULAR  2990373
# 4990  21:00:00  REGULAR  2991509
# 4991  01:00:00  REGULAR  2991823
# 4992  05:00:00  REGULAR  2991844
# 4993  09:00:00  REGULAR  2991980
# 4994  13:00:00  REGULAR  2992367
# 4995  17:00:00  REGULAR  2993207
# 4996  21:00:00  REGULAR  2994293
# 4997  01:00:00  REGULAR  2994644
# 4998  05:00:00  REGULAR  2994671
# 4999  09:00:00  REGULAR  2994803
#
#       EXITS
# 0                                               2224050
# 1                                               2224053
# 2                                               2224053
# 3                                               2224055
# 4                                               2224055
# 5                                               2224055
# 6                                               2224055
# 7                                               2224055
# 8                                               2224055
# 9                                               2224055
# 10                                              2224055
# 11                                              2224055
# 12                                              2224055
# 13                                              2224055
# 14                                              2224142
# 15                                              2224350
# 16                                              2224406
# 17                                              2224472
# 18                                              2224496
# 19                                              2224496
# 20                                              2224606
# 21                                              2224834
# 22                                              2224909
# 23                                              2225000
# 24                                              2225039
# 25                                              2225039
# 26                                              2225144
# 27                                              2225359
# 28                                              2225415
# 29                                              2225480
# ...                                                 ...
# 4970                                            2157578
# 4971                                            2157953
# 4972                                            2158165
# 4973                                            2158254
# 4974                                            2158271
# 4975                                            2158538
# 4976                                            2159027
# 4977                                            2159472
# 4978                                            2159846
# 4979                                            2159926
# 4980                                            2159937
# 4981                                            2160244
# 4982                                            2160855
# 4983                                            2161324
# 4984                                            2161709
# 4985                                            2161818
# 4986                                            2161835
# 4987                                            2162163
# 4988                                            2162785
# 4989                                            2163260
# 4990                                            2163716
# 4991                                            2163802
# 4992                                            2163814
# 4993                                            2164118
# 4994                                            2164693
# 4995                                            2165214
# 4996                                            2165696
# 4997                                            2165822
# 4998                                            2165842
# 4999                                            2166168
#
# [5000 rows x 11 columns]

# %% [markdown]
# # Challenge 1
# 1. Open up a new IPython notebook
# 2. Download a few MTA turnstile data files
# 3. Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
# ```
# { ('A002','R051','02-00-00','LEXINGTON AVE'): [ ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'], ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'], ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'], ... ] }
# ```

# %%
def create_dict(mtaData):
    result = {}
    for index, d in mtaData.iterrows():
        key = (d['C/A'], d['UNIT'], d['SCP'], d['STATION'])
        if key in result:
            result[key].append(list(d[4:]))
        else:
            result[key]=[list(d[4:])]
        return result;
result = create_dict(data)
print(result.keys())
# Out:
# dict_keys([('A002', 'R051', '02-00-00', '59 ST')])

# %%
print(result)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [['NQR456W', 'BMT', '03/31/2018', '00:00:00', 'REGULAR', 6566463, 2224050]]}

# %% [markdown]
# # Challenge 2
# Let's turn this into a time series.
# For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the dateutil module to convert it into a datetime object. For an example check this StackOverflow question.
#
# Your new dict should look something like
#
# { ('A002','R051','02-00-00','LEXINGTON AVE'): [ [datetime.datetime(2013, 3, 2, 3, 0), 3788], [datetime.datetime(2013, 3, 2, 7, 0), 2585], [datetime.datetime(2013, 3, 2, 12, 0), 10653], [datetime.datetime(2013, 3, 2, 17, 0), 11016], [datetime.datetime(2013, 3, 2, 23, 0), 10666], [datetime.datetime(2013, 3, 3, 3, 0), 10814], [datetime.datetime(2013, 3, 3, 7, 0), 10229], ... ], .... }

# %%
import dateutil.parser

# %%
def to_time_series(mtaData):
    result2 = {}
    for index, d in mtaData.iterrows():
        key = (d['C/A'], d['UNIT'], d['SCP'], d['STATION'])
        dateCurrent = dateutil.parser.parse(d.DATE +' '+d.TIME)
        currRow=[dateCurrent, d.ENTRIES]
        if key in result2:
            result2[key].append(list(currRow))
        else:
            result2[key]=[list(currRow)]
    return result2;
result2 = to_time_series(data)
print(result2)
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [[datetime.datetime(2018, 3, 31, 0, 0), 6566463], [datetime.datetime(2018, 3, 31, 4, 0), 6566470], [datetime.datetime(2018, 3, 31, 8, 0), 6566470], [datetime.datetime(2018, 3, 31, 12, 0), 6566470], [datetime.datetime(2018, 3, 31, 16, 0), 6566470], [datetime.datetime(2018, 3, 31, 20, 0), 6566470], [datetime.datetime(2018, 4, 1, 0, 0), 6566470], [datetime.datetime(2018, 4, 1, 4, 0), 6566470], [datetime.datetime(2018, 4, 1, 8, 0), 6566470], [datetime.datetime(2018, 4, 1, 12, 0), 6566470], [datetime.datetime(2018, 4, 1, 16, 0), 6566470], [datetime.datetime(2018, 4, 1, 20, 0), 6566470], [datetime.datetime(2018, 4, 2, 0, 0), 6566470], [datetime.datetime(2018, 4, 2, 4, 0), 6566470], [datetime.datetime(2018, 4, 2, 8, 0), 6566495], [datetime.datetime(2018, 4, 2, 12, 0), 6566629], [datetime.datetime(2018, 4, 2, 16, 0), 6566839], [datetime.datetime(2018, 4, 2, 20, 0), 6567469], [datetime.datetime(2018, 4, 3, 0, 0), 6567630], [datetime.datetime(2018, 4, 3, 4, 0), 6567630], [datetime.datetime(2018, 4, 3, 8, 0), 6567660], [datetime.datetime(2018, 4, 3, 12, 0), 6567822], [datetime.datetime(2018, 4, 3, 16, 0), 6568094], [datetime.datetime(2018, 4, 3, 20, 0), 6568775], [datetime.datetime(2018, 4, 4, 0, 0), 6568921], [datetime.datetime(2018, 4, 4, 4, 0), 6568924], [datetime.datetime(2018, 4, 4, 8, 0), 6568955], [datetime.datetime(2018, 4, 4, 12, 0), 6569103], [datetime.datetime(2018, 4, 4, 16, 0), 6569377], [datetime.datetime(2018, 4, 4, 20, 0), 6570115], [datetime.datetime(2018, 4, 5, 0, 0), 6570307], [datetime.datetime(2018, 4, 5, 4, 0), 6570307], [datetime.datetime(2018, 4, 5, 8, 0), 6570338], [datetime.datetime(2018, 4, 5, 12, 0), 6570480], [datetime.datetime(2018, 4, 5, 16, 0), 6570768], [datetime.datetime(2018, 4, 5, 20, 0), 6571500], [datetime.datetime(2018, 4, 6, 0, 0), 6571707], [datetime.datetime(2018, 4, 6, 4, 0), 6571711], [datetime.datetime(2018, 4, 6, 8, 0), 6571742], [datetime.datetime(2018, 4, 6, 12, 0), 6571888], [datetime.datetime(2018, 4, 6, 16, 0), 6572205], [datetime.datetime(2018, 4, 6, 20, 0), 6572929]], ('A002', 'R051', '02-00-01', '59 ST'): [[datetime.datetime(2018, 3, 31, 0, 0), 5889283], [datetime.datetime(2018, 3, 31, 4, 0), 5889285], [datetime.datetime(2018, 3, 31, 8, 0), 5889285], [datetime.datetime(2018, 3, 31, 12, 0), 5889285], [datetime.datetime(2018, 3, 31, 16, 0), 5889285], [datetime.datetime(2018, 3, 31, 20, 0), 5889285], [datetime.datetime(2018, 4, 1, 0, 0), 5889285], [datetime.datetime(2018, 4, 1, 4, 0), 5889285], [datetime.datetime(2018, 4, 1, 8, 0), 5889285], [datetime.datetime(2018, 4, 1, 12, 0), 5889285], [datetime.datetime(2018, 4, 1, 16, 0), 5889285], [datetime.datetime(2018, 4, 1, 20, 0), 5889285], [datetime.datetime(2018, 4, 2, 0, 0), 5889285], [datetime.datetime(2018, 4, 2, 4, 0), 5889285], [datetime.datetime(2018, 4, 2, 8, 0), 5889304], [datetime.datetime(2018, 4, 2, 12, 0), 5889414], [datetime.datetime(2018, 4, 2, 16, 0), 5889602], [datetime.datetime(2018, 4, 2, 20, 0), 5890117], [datetime.datetime(2018, 4, 3, 0, 0), 5890241], [datetime.datetime(2018, 4, 3, 4, 0), 5890244], [datetime.datetime(2018, 4, 3, 8, 0), 5890269], [datetime.datetime(2018, 4, 3, 12, 0), 5890396], [datetime.datetime(2018, 4, 3, 16, 0), 5890623], [datetime.datetime(2018, 4, 3, 20, 0), 5891152], [datetime.datetime(2018, 4, 4, 0, 0), 5891274], [datetime.datetime(2018, 4, 4, 4, 0), 5891275], [datetime.datetime(2018, 4, 4, 8, 0), 5891294], [datetime.datetime(2018, 4, 4, 12, 0), 5891411], [datetime.datetime(2018, 4, 4, 16, 0), 5891654], [datetime.datetime(2018, 4, 4, 20, 0), 5892222], [datetime.datetime(2018, 4, 5, 0, 0), 5892368], [datetime.datetime(2018, 4, 5, 4, 0), 5892371], [datetime.datetime(2018, 4, 5, 8, 0), 5892396], [datetime.datetime(2018, 4, 5, 12, 0), 5892522], [datetime.datetime(2018, 4, 5, 16, 0), 5892760], [datetime.datetime(2018, 4, 5, 20, 0), 5893342], [datetime.datetime(2018, 4, 6, 0, 0), 5893483], [datetime.datetime(2018, 4, 6, 4, 0), 5893484], [datetime.datetime(2018, 4, ...

# %% [markdown]
# # Challenge 3
# These counts are for every n hours. (What is n?) We want total daily entries.
# Now make it that we again have the same keys, but now we have a single value for a single day, which is the total number of passengers that entered through this turnstile on this day.

# %%
import sys
'''
def to_daily_entries(dailydata):
    resultT = {}
    for key, value in dailydata.items():
        date = '';
        min = sys.maxsize
        max = -sys.maxsize -1
        resultT[key] = {}    
        for v in value:
            trackingDate = v[0].date()
            date = v[0].date()
            if date == trackingDate:
                if min>v[-1]:
                    min = v[-1]
                elif max<v[-1]:
                    max = v[-1]
                resultT[key][trackingDate]=max-min  
            else:
                min = v[-1]
                max = -sys.maxsize -1
    return resultT;
result3=to_daily_entries(result2)
print(result3)

'''
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): {datetime.date(2018, 3, 31): 7, datetime.date(2018, 4, 1): 7, datetime.date(2018, 4, 2): 1006, datetime.date(2018, 4, 3): 2312, datetime.date(2018, 4, 4): 3652, datetime.date(2018, 4, 5): 5037, datetime.date(2018, 4, 6): 6466}, ('A002', 'R051', '02-00-01', '59 ST'): {datetime.date(2018, 3, 31): 2, datetime.date(2018, 4, 1): 2, datetime.date(2018, 4, 2): 834, datetime.date(2018, 4, 3): 1869, datetime.date(2018, 4, 4): 2939, datetime.date(2018, 4, 5): 4059, datetime.date(2018, 4, 6): 5162}, ('A002', 'R051', '02-03-00', '59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 352, datetime.date(2018, 4, 3): 785, datetime.date(2018, 4, 4): 1256, datetime.date(2018, 4, 5): 1767, datetime.date(2018, 4, 6): 2276}, ('A002', 'R051', '02-03-01', '59 ST'): {datetime.date(2018, 3, 31): 3, datetime.date(2018, 4, 1): 3, datetime.date(2018, 4, 2): 903, datetime.date(2018, 4, 3): 2104, datetime.date(2018, 4, 4): 3317, datetime.date(2018, 4, 5): 4575, datetime.date(2018, 4, 6): 5809}, ('A002', 'R051', '02-03-02', '59 ST'): {datetime.date(2018, 3, 31): 5, datetime.date(2018, 4, 1): 5, datetime.date(2018, 4, 2): 985, datetime.date(2018, 4, 3): 2316, datetime.date(2018, 4, 4): 3627, datetime.date(2018, 4, 5): 4961, datetime.date(2018, 4, 6): 6255}, ('A002', 'R051', '02-03-03', '59 ST'): {datetime.date(2018, 3, 31): 9, datetime.date(2018, 4, 1): 9, datetime.date(2018, 4, 2): 982, datetime.date(2018, 4, 3): 2225, datetime.date(2018, 4, 4): 3421, datetime.date(2018, 4, 5): 4667, datetime.date(2018, 4, 6): 5900}, ('A002', 'R051', '02-03-04', '59 ST'): {datetime.date(2018, 3, 31): 5, datetime.date(2018, 4, 1): 5, datetime.date(2018, 4, 2): 1072, datetime.date(2018, 4, 3): 2462, datetime.date(2018, 4, 4): 3756, datetime.date(2018, 4, 5): 5211, datetime.date(2018, 4, 6): 6549}, ('A002', 'R051', '02-03-05', '59 ST'): {datetime.date(2018, 3, 31): 18, datetime.date(2018, 4, 1): 18, datetime.date(2018, 4, 2): 1543, datetime.date(2018, 4, 3): 3549, datetime.date(2018, 4, 4): 5614, datetime.date(2018, 4, 5): 7691, datetime.date(2018, 4, 6): 9572}, ('A002', 'R051', '02-03-06', '59 ST'): {datetime.date(2018, 3, 31): 2, datetime.date(2018, 4, 1): 2, datetime.date(2018, 4, 2): 1290, datetime.date(2018, 4, 3): 2964, datetime.date(2018, 4, 4): 4704, datetime.date(2018, 4, 5): 6439, datetime.date(2018, 4, 6): 8108}, ('A002', 'R051', '02-05-00', '59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 0, datetime.date(2018, 4, 3): 2, datetime.date(2018, 4, 4): 2, datetime.date(2018, 4, 5): 4, datetime.date(2018, 4, 6): 5}, ('A002', 'R051', '02-05-01', '59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 0, datetime.date(2018, 4, 3): 0, datetime.date(2018, 4, 4): 0, datetime.date(2018, 4, 5): 0, datetime.date(2018, 4, 6): 0}, ('A002', 'R051', '02-06-00', '59 ST'): {datetime.date(2018, 3, 31): 7, datetime.date(2018, 4, 1): 7, datetime.date(2018, 4, 2): 874, datetime.date(2018, 4, 3): 2010, datetime.date(2018, 4, 4): 3172, datetime.date(2018, 4, 5): 4378, datetime.date(2018, 4, 6): 5440}, ('A006', 'R079', '00-00-00', '5 AV/59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 1354, datetime.date(2018, 4, 3): 2909, datetime.date(2018, 4, 4): 4432, datetime.date(2018, 4, 5): 6013, datetime.date(2018, 4, 6): 7477}, ('A006', 'R079', '00-00-01', '5 AV/59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 1198, datetime.date(2018, 4, 3): 2678, datetime.date(2018, 4, 4): 4188, datetime.date(2018, 4, 5): 5676, datetime.date(2018, 4, 6): 7088}, ('A006', 'R079', '00-00-02', '5 AV/59 ST'): {datetime.date(2018, 3, 31): 0, datetime.date(2018, 4, 1): 0, datetime.date(2018, 4, 2): 958, datetime.date(2018, 4, 3): 2173, datetime.date(2018, 4, 4): 3337, datetime.date(2018, 4, 5): 4581, datetime.date(2018, 4, 6): 5644}, ('A006', 'R079' ...

# %%
# Alternative solution (needs optimizing to skip intermediate rows)
def to_daily_entries2(dailydata):
    resultT = {}
    for key, series in dailydata.items():
        new_series = []
        # Assuming series is sorted chronologically
        first_of_current_date = series[0]
        current_date = first_of_current_date[0].date()
        for x in series:
            if x[0].date() != current_date:
                count = x[1] - first_of_current_date[1]
                new_series.append([current_date, count])
                first_of_current_date = x
                current_date = x[0].date()
        resultT[key] = new_series
    return resultT;
    
result3 = to_daily_entries2(result2)
result3
# Out:
# {('A002', 'R051', '02-00-00', '59 ST'): [[datetime.date(2018, 3, 31), 7],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1160],
#   [datetime.date(2018, 4, 3), 1291],
#   [datetime.date(2018, 4, 4), 1386],
#   [datetime.date(2018, 4, 5), 1400]],
#  ('A002', 'R051', '02-00-01', '59 ST'): [[datetime.date(2018, 3, 31), 2],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 956],
#   [datetime.date(2018, 4, 3), 1033],
#   [datetime.date(2018, 4, 4), 1094],
#   [datetime.date(2018, 4, 5), 1115]],
#  ('A002', 'R051', '02-03-00', '59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 408],
#   [datetime.date(2018, 4, 3), 439],
#   [datetime.date(2018, 4, 4), 469],
#   [datetime.date(2018, 4, 5), 547]],
#  ('A002', 'R051', '02-03-01', '59 ST'): [[datetime.date(2018, 3, 31), 3],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1093],
#   [datetime.date(2018, 4, 3), 1222],
#   [datetime.date(2018, 4, 4), 1237],
#   [datetime.date(2018, 4, 5), 1264]],
#  ('A002', 'R051', '02-03-02', '59 ST'): [[datetime.date(2018, 3, 31), 5],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1154],
#   [datetime.date(2018, 4, 3), 1351],
#   [datetime.date(2018, 4, 4), 1324],
#   [datetime.date(2018, 4, 5), 1346]],
#  ('A002', 'R051', '02-03-03', '59 ST'): [[datetime.date(2018, 3, 31), 9],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1139],
#   [datetime.date(2018, 4, 3), 1220],
#   [datetime.date(2018, 4, 4), 1228],
#   [datetime.date(2018, 4, 5), 1255]],
#  ('A002', 'R051', '02-03-04', '59 ST'): [[datetime.date(2018, 3, 31), 5],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1235],
#   [datetime.date(2018, 4, 3), 1381],
#   [datetime.date(2018, 4, 4), 1333],
#   [datetime.date(2018, 4, 5), 1449]],
#  ('A002', 'R051', '02-03-05', '59 ST'): [[datetime.date(2018, 3, 31), 18],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1812],
#   [datetime.date(2018, 4, 3), 2019],
#   [datetime.date(2018, 4, 4), 2128],
#   [datetime.date(2018, 4, 5), 2012]],
#  ('A002', 'R051', '02-03-06', '59 ST'): [[datetime.date(2018, 3, 31), 2],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1489],
#   [datetime.date(2018, 4, 3), 1698],
#   [datetime.date(2018, 4, 4), 1740],
#   [datetime.date(2018, 4, 5), 1718]],
#  ('A002', 'R051', '02-05-00', '59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1],
#   [datetime.date(2018, 4, 3), 1],
#   [datetime.date(2018, 4, 4), 0],
#   [datetime.date(2018, 4, 5), 2]],
#  ('A002', 'R051', '02-05-01', '59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 0],
#   [datetime.date(2018, 4, 3), 0],
#   [datetime.date(2018, 4, 4), 0],
#   [datetime.date(2018, 4, 5), 0]],
#  ('A002', 'R051', '02-06-00', '59 ST'): [[datetime.date(2018, 3, 31), 7],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 989],
#   [datetime.date(2018, 4, 3), 1149],
#   [datetime.date(2018, 4, 4), 1154],
#   [datetime.date(2018, 4, 5), 1224]],
#  ('A006', 'R079', '00-00-00', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1466],
#   [datetime.date(2018, 4, 3), 1538],
#   [datetime.date(2018, 4, 4), 1533],
#   [datetime.date(2018, 4, 5), 1589]],
#  ('A006', 'R079', '00-00-01', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1277],
#   [datetime.date(2018, 4, 3), 1468],
#   [datetime.date(2018, 4, 4), 1513],
#   [datetime.date(2018, 4, 5), 1496]],
#  ('A006', 'R079', '00-00-02', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1006],
#   [datetime.date(2018, 4, 3), 1207],
#   [datetime.date(2018, 4, 4), 1172],
#   [datetime.date(2018, 4, 5), 1241]],
#  ('A006', 'R079', '00-00-03', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 887],
#   [datetime.date(2018, 4, 3), 1049],
#   [datetime.date(2018, 4, 4), 947],
#   [datetime.date(2018, 4, 5), 1119]],
#  ('A006', 'R079', '00-00-04', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 1],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 752],
#   [datetime.date(2018, 4, 3), 933],
#   [datetime.date(2018, 4, 4), 869],
#   [datetime.date(2018, 4, 5), 1029]],
#  ('A006', 'R079', '00-03-00', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1105],
#   [datetime.date(2018, 4, 3), 1244],
#   [datetime.date(2018, 4, 4), 1226],
#   [datetime.date(2018, 4, 5), 1419]],
#  ('A006', 'R079', '00-03-01', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1465],
#   [datetime.date(2018, 4, 3), 1621],
#   [datetime.date(2018, 4, 4), 1694],
#   [datetime.date(2018, 4, 5), 1759]],
#  ('A006', 'R079', '00-03-02', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 2001],
#   [datetime.date(2018, 4, 3), 2289],
#   [datetime.date(2018, 4, 4), 2254],
#   [datetime.date(2018, 4, 5), 2353]],
#  ('A007', 'R079', '01-05-00', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 0],
#   [datetime.date(2018, 4, 3), 0],
#   [datetime.date(2018, 4, 4), 0],
#   [datetime.date(2018, 4, 5), 0]],
#  ('A007', 'R079', '01-05-01', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 0],
#   [datetime.date(2018, 4, 3), 0],
#   [datetime.date(2018, 4, 4), 0],
#   [datetime.date(2018, 4, 5), 0]],
#  ('A007', 'R079', '01-06-00', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 1],
#   [datetime.date(2018, 4, 2), 434],
#   [datetime.date(2018, 4, 3), 340],
#   [datetime.date(2018, 4, 4), 511],
#   [datetime.date(2018, 4, 5), 604]],
#  ('A007', 'R079', '01-06-01', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 1],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 1245],
#   [datetime.date(2018, 4, 3), 1402],
#   [datetime.date(2018, 4, 4), 1401],
#   [datetime.date(2018, 4, 5), 1530]],
#  ('A007', 'R079', '01-06-02', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 5],
#   [datetime.date(2018, 4, 1), 3],
#   [datetime.date(2018, 4, 2), 863],
#   [datetime.date(2018, 4, 3), 807],
#   [datetime.date(2018, 4, 4), 980],
#   [datetime.date(2018, 4, 5), 1165]],
#  ('A007', 'R079', '01-06-03', '5 AV/59 ST'): [[datetime.date(2018, 3, 31), 3],
#   [datetime.date(2018, 4, 1), 5],
#   [datetime.date(2018, 4, 2), 1528],
#   [datetime.date(2018, 4, 3), 1458],
#   [datetime.date(2018, 4, 4), 1609],
#   [datetime.date(2018, 4, 5), 1790]],
#  ('A010',
#   'R080',
#   '00-00-00',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1783], [datetime.date(2018, 4, 1), 1585], [datetime.date(2018, 4, 2),
#    2350], [datetime.date(2018, 4, 3), 2703], [datetime.date(2018, 4, 4),
#    2663], [datetime.date(2018, 4, 5), 785]],
#  ('A010',
#   'R080',
#   '00-00-01',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    766], [datetime.date(2018, 4, 1), 630], [datetime.date(2018, 4, 2),
#    1599], [datetime.date(2018, 4, 3), 1904], [datetime.date(2018, 4, 4),
#    1786], [datetime.date(2018, 4, 5), 3113]],
#  ('A010',
#   'R080',
#   '00-00-02',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1321], [datetime.date(2018, 4, 1), 1030], [datetime.date(2018, 4, 2),
#    1299], [datetime.date(2018, 4, 3), 1587], [datetime.date(2018, 4, 4),
#    1348], [datetime.date(2018, 4, 5), 1880]],
#  ('A010',
#   'R080',
#   '00-00-03',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    924], [datetime.date(2018, 4, 1), 708], [datetime.date(2018, 4, 2),
#    1184], [datetime.date(2018, 4, 3), 1510], [datetime.date(2018, 4, 4),
#    1322], [datetime.date(2018, 4, 5), 1537]],
#  ('A010',
#   'R080',
#   '00-00-04',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1310], [datetime.date(2018, 4, 1), 1001], [datetime.date(2018, 4, 2),
#    1562], [datetime.date(2018, 4, 3), 2093], [datetime.date(2018, 4, 4),
#    1720], [datetime.date(2018, 4, 5), 1771]],
#  ('A010',
#   'R080',
#   '00-00-05',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    915], [datetime.date(2018, 4, 1), 613], [datetime.date(2018, 4, 2),
#    2271], [datetime.date(2018, 4, 3), 3245], [datetime.date(2018, 4, 4),
#    2626], [datetime.date(2018, 4, 5), 2508]],
#  ('A010',
#   'R080',
#   '00-00-06',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    2065], [datetime.date(2018, 4, 1), 1500], [datetime.date(2018, 4, 2),
#    3822], [datetime.date(2018, 4, 3), 6234], [datetime.date(2018, 4, 4),
#    4150], [datetime.date(2018, 4, 5), 3518]],
#  ('A010',
#   'R080',
#   '00-00-07',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    3423], [datetime.date(2018, 4, 1), 2633], [datetime.date(2018, 4, 2),
#    3041], [datetime.date(2018, 4, 3), 0], [datetime.date(2018, 4, 4),
#    4015], [datetime.date(2018, 4, 5), 5437]],
#  ('A011',
#   'R080',
#   '01-00-00',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    -2157], [datetime.date(2018, 4, 1), -1597], [datetime.date(2018, 4, 2),
#    -3228], [datetime.date(2018, 4, 3), -3845], [datetime.date(2018, 4, 4),
#    -3742], [datetime.date(2018, 4, 5), -3849]],
#  ('A011',
#   'R080',
#   '01-00-01',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1491], [datetime.date(2018, 4, 1), 1094], [datetime.date(2018, 4, 2),
#    2658], [datetime.date(2018, 4, 3), 3095], [datetime.date(2018, 4, 4),
#    3241], [datetime.date(2018, 4, 5), 3221]],
#  ('A011',
#   'R080',
#   '01-00-02',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1024], [datetime.date(2018, 4, 1), 783], [datetime.date(2018, 4, 2),
#    2046], [datetime.date(2018, 4, 3), 2458], [datetime.date(2018, 4, 4),
#    2660], [datetime.date(2018, 4, 5), 2516]],
#  ('A011',
#   'R080',
#   '01-00-03',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    984], [datetime.date(2018, 4, 1), 735], [datetime.date(2018, 4, 2),
#    1837], [datetime.date(2018, 4, 3), 2337], [datetime.date(2018, 4, 4),
#    2607], [datetime.date(2018, 4, 5), 2208]],
#  ('A011',
#   'R080',
#   '01-00-04',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1166], [datetime.date(2018, 4, 1), 1006], [datetime.date(2018, 4, 2),
#    2306], [datetime.date(2018, 4, 3), 2621], [datetime.date(2018, 4, 4),
#    2863], [datetime.date(2018, 4, 5), 2577]],
#  ('A011',
#   'R080',
#   '01-00-05',
#   '57 ST-7 AV'): [[datetime.date(2018, 3, 31),
#    1037], [datetime.date(2018, 4, 1), 787], [datetime.date(2018, 4, 2),
#    2633], [datetime.date(2018, 4, 3), 2658], [datetime.date(2018, 4, 4),
#    2042], [datetime.date(2018, 4, 5), 2774]],
#  ('A013', 'R081', '01-00-00', '49 ST'): [[datetime.date(2018, 3, 31), 191],
#   [datetime.date(2018, 4, 1), 119],
#   [datetime.date(2018, 4, 2), 471],
#   [datetime.date(2018, 4, 3), 437],
#   [datetime.date(2018, 4, 4), 552],
#   [datetime.date(2018, 4, 5), 472]],
#  ('A013', 'R081', '01-03-00', '49 ST'): [[datetime.date(2018, 3, 31), 662],
#   [datetime.date(2018, 4, 1), 547],
#   [datetime.date(2018, 4, 2), 1199],
#   [datetime.date(2018, 4, 3), 1368],
#   [datetime.date(2018, 4, 4), 1380],
#   [datetime.date(2018, 4, 5), 1408]],
#  ('A013', 'R081', '01-03-01', '49 ST'): [[datetime.date(2018, 3, 31), 850],
#   [datetime.date(2018, 4, 1), 773],
#   [datetime.date(2018, 4, 2), 1475],
#   [datetime.date(2018, 4, 3), 1681],
#   [datetime.date(2018, 4, 4), 1625],
#   [datetime.date(2018, 4, 5), 1630]],
#  ('A013', 'R081', '01-03-02', '49 ST'): [[datetime.date(2018, 3, 31), 1067],
#   [datetime.date(2018, 4, 1), 900],
#   [datetime.date(2018, 4, 2), 2158],
#   [datetime.date(2018, 4, 3), 2346],
#   [datetime.date(2018, 4, 4), 2483],
#   [datetime.date(2018, 4, 5), 2438]],
#  ('A013', 'R081', '01-05-00', '49 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 0],
#   [datetime.date(2018, 4, 3), 1],
#   [datetime.date(2018, 4, 4), 0],
#   [datetime.date(2018, 4, 5), 0]],
#  ('A013', 'R081', '01-05-01', '49 ST'): [[datetime.date(2018, 3, 31), 0],
#   [datetime.date(2018, 4, 1), 0],
#   [datetime.date(2018, 4, 2), 0],
#   [datetime.date(2018, 4, 3), 0],
#   [datetime.date(2018, 4, 4), 0],
#   [datetime.date(2018, 4, 5), 0]],
#  ('A014', 'R081', '02-00-00', '49 ST'): [[datetime.date(2018, 3, 31), 1034],
#   [datetime.date(2018, 4, 1), 806],
#   [datetime.date(2018, 4, 2), 1689],
#   [datetime.date(2018, 4, 3), 1930],
#   [datetime.date(2018, 4, 4), 1944],
#   [datetime.date(2018, 4, 5), 2009]],
#  ('A014', 'R081', '02-00-01', '49 ST'): [[datetime.date(2018, 3, 31), 741],
#   [datetime.date(2018, 4, 1), 618],
#   [datetime.date(2018, 4, 2), 1138],
#   [datetime.date(2018, 4, 3), 1405],
#   [datetime.date(2018, 4, 4), 1412],
#   [datetime.date(2018, 4, 5), 1435]],
#  ('A014', 'R081', '02-00-02', '49 ST'): [[datetime.date(2018, 3, 31), 597],
#   [datetime.date(2018, 4, 1), 451],
#   [datetime.date(2018, 4, 2), 847],
#   [datetime.date(2018, 4, 3), 1066],
#   [datetime.date(2018, 4, 4), 1097],
#   [datetime.date(2018, 4, 5), 1066]],
#  ('A014', 'R081', '02-06-00', '49 ST'): [[datetime.date(2018, 3, 31), 30],
#   [datetime.date(2018, 4, 1), 23],
#   [datetime.date(2018, 4, 2), 42],
#   [datetime.date(2018, 4, 3), 41],
#   [datetime.date(2018, 4, 4), 36],
#   [datetime.date(2018, 4, 5), 52]],
#  ('A014', 'R081', '02-06-01', '49 ST'): [[datetime.date(2018, 3, 31), 6],
#   [datetime.date(2018, 4, 1), 10],
#   [datetime.date(2018, 4, 2), 6],
#   [datetime.date(2018, 4, 3), 20],
#   [datetime.date(2018, 4, 4), 12],
#   [datetime.date(2018, 4, 5), 31]],
#  ('A015', 'R081', '00-00-00', '49 ST'): [[datetime.date(2018, 3, 31), 1925],
#   [datetime.date(2018, 4, 1), 1501],
#   [datetime.date(2018, 4, 2), 2148],
#   [datetime.date(2018, 4, 3), 2493],
#   [datetime.date(2018, 4, 4), 2663],
#   [datetime.date(2018, 4, 5), 2692]],
#  ('A015', 'R081', '00-00-01', '49 ST'): [[datetime.date(2018, 3, 31), 1755],
#   [datetime.date(2018, 4, 1), 1476],
#   [datetime.date(2018, 4, 2), 1835],
#   [datetime.date(2018, 4, 3), 2094],
#   [datetime.date(2018, 4, 4), 2270],
#   [datetime.date(2018, 4, 5), 2339]],
#  ('A015', 'R081', '00-00-02', '49 ST'): [[datetime.date(2018, 3, 31), 1554],
#   [datetime.date(2018, 4, 1), 1316],
#   [datetime.date(2018, 4, 2), 1654],
#   [datetime.date(2018, 4, 3), 1933],
#   [datetime.date(2018, 4, 4), 2005],
#   [datetime.date(2018, 4, 5), 2042]],
#  ('A015', 'R081', '00-00-03', '49 ST'): [[datetime.date(2018, 3, 31), 1166],
#   [datetime.date(2018, 4, 1), 955],
#   [datetime.date(2018, 4, 2), 1267],
#   [datetime.date(2018, 4, 3), 1445],
#   [datetime.date(2018, 4, 4), 1551],
#   [datetime.date(2018, 4, 5), 1621]],
#  ('A015', 'R081', '00-03-00', '49 ST'): [[datetime.date(2018, 3, 31), 944],
#   [datetime.date(2018, 4, 1), 649],
#   [datetime.date(2018, 4, 2), 984],
#   [datetime.date(2018, 4, 3), 1193],
#   [datetime.date(2018, 4, 4), 1267],
#   [datetime.date(2018, 4, 5), 1346]],
#  ('A015', 'R081', '00-03-01', '49 ST'): [[datetime.date(2018, 3, 31), 703],
#   [datetime.date(2018, 4, 1), 505],
#   [datetime.date(2018, 4, 2), 853],
#   [datetime.date(2018, 4, 3), 1008],
#   [datetime.date(2018, 4, 4), 1234],
#   [datetime.date(2018, 4, 5), 1107]],
#  ('A016', 'R081', '03-00-00', '49 ST'): [[datetime.date(2018, 3, 31), 1128],
#   [datetime.date(2018, 4, 1), 967],
#   [datetime.date(2018, 4, 2), 1275],
#   [datetime.date(2018, 4, 3), 1584],
#   [datetime.date(2018, 4, 4), 1657],
#   [datetime.date(2018, 4, 5), 1690]],
#  ('A016', 'R081', '03-00-01', '49 ST'): [[datetime.date(2018, 3, 31), 1472],
#   [datetime.date(2018, 4, 1), 1130],
#   [datetime.date(2018, 4, 2), 1579],
#   [datetime.date(2018, 4, 3), 1846],
#   [datetime.date(2018, 4, 4), 1991],
#   [datetime.date(2018, 4, 5), 1916]],
#  ('A016', 'R081', '03-00-02', '49 ST'): [[datetime.date(2018, 3, 31), 1999],
#   [datetime.date(2018, 4, 1), 1647],
#   [datetime.date(2018, 4, 2), 2270],
#   [datetime.date(2018, 4, 3), 2648],
#   [datetime.date(2018, 4, 4), 2760],
#   [datetime.date(2018, 4, 5), 2729]],
#  ('A016', 'R081', '03-06-00', '49 ST'): [[datetime.date(2018, 3, 31), 223],
#   [datetime.date(2018, 4, 1), 122],
#   [datetime.date(2018, 4, 2), 193],
#   [datetime.date(2018, 4, 3), 209],
#   [datetime.date(2018, 4, 4), 214],
#   [datetime.date(2018, 4, 5), 288]],
#  ('A016', 'R081', '03-06-01', '49 ST'): [[datetime.date(2018, 3, 31), 114],
#   [datetime.date(2018, 4, 1), 54],
#   [datetime.date(2018, 4, 2), 110],
#   [datetime.date(2018, 4, 3), 126],
#   [datetime.date(2018, 4, 4), 99],
#   [datetime.date(2018, 4, 5), 171]],
#  ('A021',
#   'R032',
#   '01-00-00',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    1516], [datetime.date(2018, 4, 1), 1211], [datetime.date(2018, 4, 2),
#    2997], [datetime.date(2018, 4, 3), 3719], [datetime.date(2018, 4, 4),
#    3752], [datetime.date(2018, 4, 5), 3612]],
#  ('A021',
#   'R032',
#   '01-00-01',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    875], [datetime.date(2018, 4, 1), 561], [datetime.date(2018, 4, 2),
#    2488], [datetime.date(2018, 4, 3), 2670], [datetime.date(2018, 4, 4),
#    2755], [datetime.date(2018, 4, 5), 2639]],
#  ('A021',
#   'R032',
#   '01-00-02',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    590], [datetime.date(2018, 4, 1), 387], [datetime.date(2018, 4, 2),
#    1694], [datetime.date(2018, 4, 3), 1888], [datetime.date(2018, 4, 4),
#    1934], [datetime.date(2018, 4, 5), 1987]],
#  ('A021',
#   'R032',
#   '01-00-03',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    449], [datetime.date(2018, 4, 1), 246], [datetime.date(2018, 4, 2),
#    1485], [datetime.date(2018, 4, 3), 1807], [datetime.date(2018, 4, 4),
#    1773], [datetime.date(2018, 4, 5), 1734]],
#  ('A021',
#   'R032',
#   '01-00-04',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    281], [datetime.date(2018, 4, 1), 171], [datetime.date(2018, 4, 2),
#    1238], [datetime.date(2018, 4, 3), 1508], [datetime.date(2018, 4, 4),
#    1411], [datetime.date(2018, 4, 5), 1385]],
#  ('A021',
#   'R032',
#   '01-00-05',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    276], [datetime.date(2018, 4, 1), 182], [datetime.date(2018, 4, 2),
#    922], [datetime.date(2018, 4, 3), 1135], [datetime.date(2018, 4, 4),
#    1116], [datetime.date(2018, 4, 5), 1010]],
#  ('A021',
#   'R032',
#   '01-00-06',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    339], [datetime.date(2018, 4, 1), 210], [datetime.date(2018, 4, 2),
#    1239], [datetime.date(2018, 4, 3), 1437], [datetime.date(2018, 4, 4),
#    1406], [datetime.date(2018, 4, 5), 1361]],
#  ('A021',
#   'R032',
#   '01-00-07',
#   'TIMES SQ-42 ST'): [[datetime.date(2018, 3, 31),
#    709], [datetime.date(2018, 4, 1), 430], [datetime.date(2018, 4, 2),
#    2400], [datetime.date(2018, 4, 3), 2791], [datetime.date(2018, 4, 4),
#    2736], [datetime.date(2018, 4, 5), 2674]],
#  ('A022',
#   'R022',
#   '01-00-00',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    3676], [datetime.date(2018, 4, 1), 2757], [datetime.date(2018, 4, 2),
#    4791], [datetime.date(2018, 4, 3), 5209], [datetime.date(2018, 4, 4),
#    5562], [datetime.date(2018, 4, 5), 5967]],
#  ('A022',
#   'R022',
#   '01-00-01',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    3022], [datetime.date(2018, 4, 1), 2262], [datetime.date(2018, 4, 2),
#    4064], [datetime.date(2018, 4, 3), 4429], [datetime.date(2018, 4, 4),
#    4764], [datetime.date(2018, 4, 5), 5280]],
#  ('A022',
#   'R022',
#   '01-00-02',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    3411], [datetime.date(2018, 4, 1), 2320], [datetime.date(2018, 4, 2),
#    4197], [datetime.date(2018, 4, 3), 4760], [datetime.date(2018, 4, 4),
#    5249], [datetime.date(2018, 4, 5), 5572]],
#  ('A022',
#   'R022',
#   '01-06-00',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    232], [datetime.date(2018, 4, 1), 124], [datetime.date(2018, 4, 2),
#    765], [datetime.date(2018, 4, 3), 759], [datetime.date(2018, 4, 4),
#    829], [datetime.date(2018, 4, 5), 875]],
#  ('A022',
#   'R022',
#   '01-06-01',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    414], [datetime.date(2018, 4, 1), 210], [datetime.date(2018, 4, 2),
#    1229], [datetime.date(2018, 4, 3), 1315], [datetime.date(2018, 4, 4),
#    1393], [datetime.date(2018, 4, 5), 1362]],
#  ('A025',
#   'R023',
#   '01-00-00',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    1622], [datetime.date(2018, 4, 1), 1432], [datetime.date(2018, 4, 2),
#    2574], [datetime.date(2018, 4, 3), 2877], [datetime.date(2018, 4, 4),
#    2975], [datetime.date(2018, 4, 5), 3008]],
#  ('A025',
#   'R023',
#   '01-00-01',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    2030], [datetime.date(2018, 4, 1), 1901], [datetime.date(2018, 4, 2),
#    3889], [datetime.date(2018, 4, 3), 4154], [datetime.date(2018, 4, 4),
#    4130], [datetime.date(2018, 4, 5), 4367]],
#  ('A025',
#   'R023',
#   '01-00-02',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    2150], [datetime.date(2018, 4, 1), 1946], [datetime.date(2018, 4, 2),
#    4008], [datetime.date(2018, 4, 3), 4180], [datetime.date(2018, 4, 4),
#    4442], [datetime.date(2018, 4, 5), 4595]],
#  ('A025',
#   'R023',
#   '01-00-03',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    2028], [datetime.date(2018, 4, 1), 1709], [datetime.date(2018, 4, 2),
#    3784], [datetime.date(2018, 4, 3), 4143], [datetime.date(2018, 4, 4),
#    4272], [datetime.date(2018, 4, 5), 4524]],
#  ('A025',
#   'R023',
#   '01-03-00',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    2724], [datetime.date(2018, 4, 1), 2377], [datetime.date(2018, 4, 2),
#    4231], [datetime.date(2018, 4, 3), 5373], [datetime.date(2018, 4, 4),
#    5406], [datetime.date(2018, 4, 5), 5503]],
#  ('A025',
#   'R023',
#   '01-03-01',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    -4041], [datetime.date(2018, 4, 1), -3569], [datetime.date(2018, 4, 2),
#    -5997], [datetime.date(2018, 4, 3), -6656], [datetime.date(2018, 4, 4),
#    -6764], [datetime.date(2018, 4, 5), -6740]],
#  ('A025',
#   'R023',
#   '01-03-02',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    0], [datetime.date(2018, 4, 1), 0], [datetime.date(2018, 4, 2),
#    0], [datetime.date(2018, 4, 3), 0], [datetime.date(2018, 4, 4),
#    0], [datetime.date(2018, 4, 5), 0]],
#  ('A025',
#   'R023',
#   '01-06-00',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    1280], [datetime.date(2018, 4, 1), 1286], [datetime.date(2018, 4, 2),
#    2100], [datetime.date(2018, 4, 3), 2210], [datetime.date(2018, 4, 4),
#    2393], [datetime.date(2018, 4, 5), 2377]],
#  ('A025',
#   'R023',
#   '01-06-01',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    1384], [datetime.date(2018, 4, 1), 1440], [datetime.date(2018, 4, 2),
#    2051], [datetime.date(2018, 4, 3), 2247], [datetime.date(2018, 4, 4),
#    2397], [datetime.date(2018, 4, 5), 2469]],
#  ('A025',
#   'R023',
#   '01-06-02',
#   '34 ST-HERALD SQ'): [[datetime.date(2018, 3, 31),
#    514], [datetime.date(2018, 4, 1), 405], [datetime.date(2018, 4, 2),
#    1027], [datetime.date(2018, 4, 3), 1041], [datetime.date(2018, 4, 4),
#    1036], [datetime.date(2018, 4, 5), 1077]],
#  ('A027', 'R082', '01-00-00', '28 ST'): [[datetime.date(2018, 3, 31), 854],
#   [datetime.date(2018, 4, 1), 622],
#   [datetime.date(2018, 4, 2), 1530],
#   [datetime.date(2018, 4, 3), 1848],
#   [datetime.date(2018, 4, 4), 1838],
#   [datetime.date(2018, 4, 5), 1794]],
#  ('A027', 'R082', '01-03-00', '28 ST'): [[datetime.date(2018, 3, 31), 954],
#   [datetime.date(2018, 4, 1), 716],
#   [datetime.date(2018, 4, 2), 1716],
#   [datetime.date(2018, 4, 3), 2051],
#   [datetime.date(2018, 4, 4), 2010],
#   [datetime.date(2018, 4, 5), 2034]],
#  ('A027', 'R082', '01-03-01', '28 ST'): [[datetime.date(2018, 3, 31), 829],
#   [datetime.date(2018, 4, 1), 612],
#   [datetime.date(2018, 4, 2), 1393],
#   [datetime.date(2018, 4, 3), 1693],
#   [datetime.date(2018, 4, 4), 1704],
#   [datetime.date(2018, 4, 5), 1665]],
#  ('A027', 'R082', '01-03-02', '28 ST'): [[datetime.date(2018, 3, 31), 723],
#   [datetime.date(2018, 4, 1), 547],
#   [datetime.date(2018, 4, 2), 1179],
#   [datetime.date(2018, 4, 3), 1479],
#   [datetime.date(2018, 4, 4), 1408],
#   [datetime.date(2018, 4, 5), 1455]],
#  ('A027', 'R082', '01-03-03', '28 ST'): [[datetime.date(2018, 3, 31), 678],
#   [datetime.date(2018, 4, 1), 525],
#   [datetime.date(2018, 4, 2), 1120],
#   [datetime.date(2018, 4, 3), 1368],
#   [datetime.date(2018, 4, 4), 1355],
#   [datetime.date(2018, 4, 5), 1329]],
#  ('A029', 'R082', '00-00-00', '28 ST'): [[datetime.date(2018, 3, 31), 523],
#   [datetime.date(2018, 4, 1), 369],
#   [datetime.date(2018, 4, 2), 696],
#   [datetime.date(2018, 4, 3), 959],
#   [datetime.date(2018, 4, 4), 870],
#   [datetime.date(2018, 4, 5), 989]],
#  ('A029', 'R082', '00-00-01', '28 ST'): [[datetime.date(2018, 3, 31), 898],
#   [datetime.date(2018, 4, 1), 651],
#   [datetime.date(2018, 4, 2), 1224],
#   [datetime.date(2018, 4, 3), 1615],
#   [datetime.date(2018, 4, 4), 1581],
#   [datetime.date(2018, 4, 5), 1639]],
#  ('A029', 'R082', '00-03-00', '28 ST'): [[datetime.date(2018, 3, 31), 1141],
#   [datetime.date(2018, 4, 1), 786],
#   [datetime.date(2018, 4, 2), 1544],
#   [datetime.date(2018, 4, 3), 1850],
#   [datetime.date(2018, 4, 4), 1750],
#   [datetime.date(2018, 4, 5), 2054]],
#  ('A029', 'R082', '00-03-01', '28 ST'): [[datetime.date(2018, 3, 31), 1322],
#   [datetime.date(2018, 4, 1), 916],
#   [datetime.date(2018, 4, 2), 1714],
#   [datetime.date(2018, 4, 3), 2046],
#   [datetime.date(2018, 4, 4), 2015],
#   [datetime.date(2018, 4, 5), 1750]],
#  ('A030', 'R083', '01-00-00', '23 ST'): [[datetime.date(2018, 3, 31), 949],
#   [datetime.date(2018, 4, 1), 671],
#   [datetime.date(2018, 4, 2), 1542],
#   [datetime.date(2018, 4, 3), 1785],
#   [datetime.date(2018, 4, 4), 1805],
#   [datetime.date(2018, 4, 5), 1790]],
#  ('A030', 'R083', '01-00-01', '23 ST'): [[datetime.date(2018, 3, 31), 719],
#   [datetime.date(2018, 4, 1), 496],
#   [datetime.date(2018, 4, 2), 1017],
#   [datetime.date(2018, 4, 3), 1206],
#   [datetime.date(2018, 4, 4), 1232],
#   [datetime.date(2018, 4, 5), 1302]],
#  ('A030', 'R083', '01-00-02', '23 ST'): [[datetime.date(2018, 3, 31), 656],
#   [datetime.date(2018, 4, 1), 423],
#   [datetime.date(2018, 4, 2), 930],
#   [datetime.date(2018, 4, 3), 1127],
#   [datetime.date(2018, 4, 4), 1105],
#   [datetime.date(2018, 4, 5), 1129]],
#  ('A030', 'R083', '01-03-00', '23 ST'): [[datetime.date(2018, 3, 31), 881],
#   [datetime.date(2018, 4, 1), 575],
#   [datetime.date(2018, 4, 2), 1265],
#   [datetime.date(2018, 4, 3), 1424],
#   [datetime.date(2018, 4, 4), 1471],
#   [datetime.date(2018, 4, 5), 1532]],
#  ('A030', 'R083', '01-03-01', '23 ST'): [[datetime.date(2018, 3, 31), 1089],
#   [datetime.date(2018, 4, 1), 796],
#   [datetime.date(2018, 4, 2), 1801],
#   [datetime.date(2018, 4, 3), 1964],
#   [datetime.date(2018, 4, 4), 2036],
#   [datetime.date(2018, 4, 5), 2183]],
#  ('A030', 'R083', '01-03-02', '23 ST'): [[datetime.date(2018, 3, 31), 1748],
#   [datetime.date(2018, 4, 1), 1235],
#   [datetime.date(2018, 4, 2), 2818],
#   [datetime.date(2018, 4, 3), 3305],
#   [datetime.date(2018, 4, 4), 3322],
#   [datetime.date(2018, 4, 5), 3456]],
#  ('A030', 'R083', '01-06-00', '23 ST'): [[datetime.date(2018, 3, 31), 869],
#   [datetime.date(2018, 4, 1), 621],
#   [datetime.date(2018, 4, 2), 1950],
#   [datetime.date(2018, 4, 3), 2351],
#   [datetime.date(2018, 4, 4), 2322],
#   [datetime.date(2018, 4, 5), 2257]],
#  ('A030', 'R083', '01-06-01', '23 ST'): [[datetime.date(2018, 3, 31), 536],
#   [datetime.date(2018, 4, 1), 344],
#   [datetime.date(2018, 4, 2), 1191],
#   [datetime.date(2018, 4, 3), 1480],
#   [datetime.date(2018, 4, 4), 1492],
#   [datetime.date(2018, 4, 5), 1553]],
#  ('A031', 'R083', '00-00-00', '23 ST'): [[datetime.date(2018, 3, 31), 1661],
#   [datetime.date(2018, 4, 1), 1057],
#   [datetime.date(2018, 4, 2), 2253],
#   [datetime.date(2018, 4, 3), 2765],
#   [datetime.date(2018, 4, 4), 2901],
#   [datetime.date(2018, 4, 5), 2776]],
#  ('A031', 'R083', '00-00-01', '23 ST'): [[datetime.date(2018, 3, 31), 1292],
#   [datetime.date(2018, 4, 1), 764],
#   [datetime.date(2018, 4, 2), 1610],
#   [datetime.date(2018, 4, 3), 1878],
#   [datetime.date(2018, 4, 4), 2116],
#   [datetime.date(2018, 4, 5), 2002]],
#  ('A031', 'R083', '00-00-02', '23 ST'): [[datetime.date(2018, 3, 31), 1038],
#   [datetime.date(2018, 4, 1), 636],
#   [datetime.date(2018, 4, 2), 1301],
#   [datetime.date(2018, 4, 3), 1567],
#   [datetime.date(2018, 4, 4), 1603],
#   [datetime.date(2018, 4, 5), 1539]],
#  ('A031', 'R083', '00-03-00', '23 ST'): [[datetime.date(2018, 3, 31), 397],
#   [datetime.date(2018, 4, 1), 303],
#   [datetime.date(2018, 4, 2), 569],
#   [datetime.date(2018, 4, 3), 684],
#   [datetime.date(2018, 4, 4), 675],
#   [datetime.date(2018, 4, 5), 765]],
#  ('A031', 'R083', '00-03-01', '23 ST'): [[datetime.date(2018, 3, 31), 588],
#   [datetime.date(2018, 4, 1), 441],
#   [datetime.date(2018, 4, 2), 806],
#   [datetime.date(2018, 4, 3), 970],
#   [datetime.date(2018, 4, 4), 967],
#   [datetime.date(2018, 4, 5), 1058]],
#  ('A031', 'R083', '00-03-02', '23 ST'): [[datetime.date(2018, 3, 31), 911],
#   [datetime.date(2018, 4, 1), 684],
#   [datetime.date(2018, 4, 2), 1457],
#   [datetime.date(2018, 4, 3), 1812],
#   [datetime.date(2018, 4, 4), 1718],
#   [datetime.date(2018, 4, 5), 1687]],
#  ('A033',
#   'R170',
#   '02-00-00',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    511], [datetime.date(2018, 4, 1), 261], [datetime.date(2018, 4, 2),
#    1071], [datetime.date(2018, 4, 3), 1192], [datetime.date(2018, 4, 4),
#    1258], [datetime.date(2018, 4, 5), 1191]],
#  ('A033',
#   'R170',
#   '02-00-01',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    823], [datetime.date(2018, 4, 1), 471], [datetime.date(2018, 4, 2),
#    1659], [datetime.date(2018, 4, 3), 2079], [datetime.date(2018, 4, 4),
#    2092], [datetime.date(2018, 4, 5), 2217]],
#  ('A033',
#   'R170',
#   '02-00-02',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    1285], [datetime.date(2018, 4, 1), 765], [datetime.date(2018, 4, 2),
#    2297], [datetime.date(2018, 4, 3), 2543], [datetime.date(2018, 4, 4),
#    2745], [datetime.date(2018, 4, 5), 2770]],
#  ('A033',
#   'R170',
#   '02-00-03',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    2113], [datetime.date(2018, 4, 1), 1347], [datetime.date(2018, 4, 2),
#    3020], [datetime.date(2018, 4, 3), 3617], [datetime.date(2018, 4, 4),
#    3590], [datetime.date(2018, 4, 5), 3783]],
#  ('A033',
#   'R170',
#   '02-00-04',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    3077], [datetime.date(2018, 4, 1), 2037], [datetime.date(2018, 4, 2),
#    4416], [datetime.date(2018, 4, 3), 5323], [datetime.date(2018, 4, 4),
#    5163], [datetime.date(2018, 4, 5), 5479]],
#  ('A033',
#   'R170',
#   '02-00-05',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    4103], [datetime.date(2018, 4, 1), 2769], [datetime.date(2018, 4, 2),
#    5621], [datetime.date(2018, 4, 3), 6674], [datetime.date(2018, 4, 4),
#    6620], [datetime.date(2018, 4, 5), 6852]],
#  ('A033',
#   'R170',
#   '02-06-00',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    44], [datetime.date(2018, 4, 1), 22], [datetime.date(2018, 4, 2),
#    228], [datetime.date(2018, 4, 3), 272], [datetime.date(2018, 4, 4),
#    253], [datetime.date(2018, 4, 5), 273]],
#  ('A033',
#   'R170',
#   '02-06-01',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    1045], [datetime.date(2018, 4, 1), 627], [datetime.date(2018, 4, 2),
#    2202], [datetime.date(2018, 4, 3), 2455], [datetime.date(2018, 4, 4),
#    2497], [datetime.date(2018, 4, 5), 2544]],
#  ('A034',
#   'R170',
#   '03-00-00',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    612], [datetime.date(2018, 4, 1), 386], [datetime.date(2018, 4, 2),
#    521], [datetime.date(2018, 4, 3), 449], [datetime.date(2018, 4, 4),
#    582], [datetime.date(2018, 4, 5), 622]],
#  ('A034',
#   'R170',
#   '03-00-01',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    1212], [datetime.date(2018, 4, 1), 766], [datetime.date(2018, 4, 2),
#    1176], [datetime.date(2018, 4, 3), 1148], [datetime.date(2018, 4, 4),
#    1375], [datetime.date(2018, 4, 5), 1332]],
#  ('A034',
#   'R170',
#   '03-00-02',
#   '14 ST-UNION SQ'): [[datetime.date(2018, 3, 31),
#    2144], [datetime.date(2018, 4, 1), 1388], [datetime.date(2018, 4, 2),
#    2391], [datetime.date(2018, 4, 3), 2389], [datetime.date(2018, 4, 4),
#    2789], [datetime.date(2018, 4, 5), 2821]]}

# %% [markdown]
# # Challenge 4
#
# We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
#     %matplotlib inline
#
# This will make your matplotlib graphs integrate nicely with the
# notebook. To plot the time series, import matplotlib with
#
#     import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the
# turnstile and turn it into two lists:
# dates and counts. This should plot it:
#
#     plt.figure(figsize=(10,3))
#     plt.plot(dates,counts)

# %%
turnstile = list(result2.keys())[0]
dates, counts = zip(*result2[turnstile])
plt.figure(figsize=(10,3))
plt.plot(dates, counts);

# %% [markdown]
# # Challenge 5
#
# - So far we've been operating on a single turnstile level, let's
#   combine turnstiles in the same ControlArea/Unit/Station combo. There
#   are some ControlArea/Unit/Station groups that have a single
#   turnstile, but most have multiple turnstilea-- same value for the
#   C/A, UNIT and STATION columns, different values for the SCP column.
#
# We want to combine the numbers together -- for each
# ControlArea/UNIT/STATION combo, for each day, add the counts from each
# turnstile belonging to that combo.

# %%
def to_turnstiles_total(dailyEntriesData):
    resultT = {}
    for key, value in dailyEntriesData.items():
        for keyC, valueC in value.items():
            newKey = (key[0],key[1],key[3], keyC )
            if newKey not in resultT:
                resultT[newKey] = 0
            resultT[newKey]+=valueC            
    return resultT
result4 = to_turnstiles_total(result3)
print(result4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-89483500da25> in <module>()
#       8             resultT[newKey]+=valueC
#       9     return resultT
# ---> 10 result4 = to_turnstiles_total(result3)
#      11 print(result4)
#      12
#
# <ipython-input-54-89483500da25> in to_turnstiles_total(dailyEntriesData)
#       2     resultT = {}
#       3     for key, value in dailyEntriesData.items():
# ----> 4         for keyC, valueC in value.items():
#       5             newKey = (key[0],key[1],key[3], keyC )
#       6             if newKey not in resultT:
#
# AttributeError: 'list' object has no attribute 'items'

# %% [markdown]
# # Challenge 6
#
# Similarly, combine everything in each station, and come up with a time
# series of `[(date1, count1),(date2,count2),...]` type of time series
# for each STATION, by adding up all the turnstiles in a station.

# %%
def to_station_total(turnstilesTotal):
    resultT = {}
             
    return resultT

result5 = to_station_total(result4)
print(result5)

# %% [markdown]
# # Challenge 7
#
# Plot the time series for a station.

# %% [markdown]
# # Challenge 8
#
# - Make one list of counts for **one** week for one station. Monday's
# count, Tuesday's count, etc. so it's a list of 7 counts.
# Make the same list for another week, and another week, and another
# week.
# `plt.plot(week_count_list)` for every `week_count_list` you created
# this way. You should get a rainbow plot of weekly commute numbers on
# top of each other.

# %% [markdown]
# # Challenge 9
#
# - Over multiple weeks, sum total ridership for each station and sort
#   them, so you can find out the stations with the highest traffic
#   during the time you investigate

# %% [markdown]
# # Challenge 10
#
# - Make a single list of these total ridership values and plot it with
#
#     plt.hist(total_ridership_counts)
#
# to get an idea about the distribution of total ridership among
# different stations.
#
# This should show you that most stations have a small traffic, and the
# histogram bins for large traffic volumes have small bars.
#
# *Additional Hint*:
#
# If you want to see which stations take the meat of the traffic, you
# can sort the total ridership counts and make a `plt.bar` graph. For
# this, you want to have two lists: the indices of each bar, and the
# values. The indices can just be `0,1,2,3,...`, so you can do
#
#     indices = range(len(total_ridership_values))
#     plt.bar(indices, total_ridership_values)

# %%
data.STATION.unique()

# %%
data.STATION.value_counts()

# %%
data.STATION.value_counts().keys()

# %%
data.STATION.value_counts().plot(kind='barh')

# %%
stops = pd.read_csv('data/stops.txt')
stops.head()

# %%
stops.stop_name.value_counts()

# %%
#dict(stops.groupby('stop_name')['stop_lat', 'stop_lon'].apply(dict))
#np.unique(stops[['stop_name', 'stop_lat', 'stop_lon']].values)
#pd.unique(stops[['stop_name', 'stop_lat', 'stop_lon']].values)
resultT = dict(stops.drop_duplicates('stop_name').groupby(['stop_name','stop_lat', 'stop_lon'])['stop_name'].apply(list))
stops_dict = resultT.keys()

# %%
#for key, value in result3.items():

# %%
#run pip3 install gmaps beforehand
# %matplotlib inline
import gmaps
import math
gmaps.configure(api_key="AIzaSyCM2FKc59VWg6jMI8nj9kN1Gii3DHsGNnE")
location_columns = stops[['stop_lat', 'stop_lon']]
location_tuples = [tuple(x) for x in location_columns.values]
fig = gmaps.figure(zoom_level=12, center=(40.7, -73.9))
fig.add_layer(gmaps.heatmap_layer(location_tuples))
#stops_layer = gmaps.symbol_layer(location_columns, fill_color="green", stroke_color="green", scale=2)
#fig.add_layer(stops_layer)

fig

# %%
trips = pd.read_csv('data/trips.txt')
trips.head()

# %%
routes = pd.read_csv('data/routes.txt')
routes.head()

# %% [markdown]
# # Other data set

# %%
import urllib.request
import requests
headers = {"Authorization":"Bearer 421BA_xYdh0Xq7dGFe1pkaI7WqWnJ5UcHZZgg8WwNQ34_7GlbvrRU4dnCGE9dmXOZrX5xVFquiL9X4B35qBuBcA4Jt1D9ys3h0z6pxnfFd8Frf9UYXQ9xKMDOnjNWnYx"}
endpoint = 'https://api.yelp.com/v3/businesses/search?location=new york&limit=50'

#yelpData = requests.get(endpoint,headers=headers).json()

# %%
#print(yelpData)
yData= yelpData['businesses']
print(len(yData))
for r in yData:
    pp.pprint(r)
    #pp.pprint(r['coordinates'])
